# %%
'''
===========================
nympha_ellipse
===========================

Demonstrates a flower of nymphaea as 3D surface(ellipsoid) objects.

'''

from mpl_toolkits.mplot3d import Axes3D
from matplotlib.patches import Circle
import mpl_toolkits.mplot3d.art3d as art3d
import matplotlib.pyplot as plt
import numpy as np
import csv
import os

# setting organ
class Organ :
	def __init__(self, rx, ry, rz, xdeg, zdeg, zpo, hb, col, reso):

		self.rx = rx #minor length
		self.ry = ry #major length
		self.rz = rz 

		self.reso = reso #surfaces resolution

#organ's shape as ellipsoid surface
		u = np.linspace(0, 2 * np.pi, reso)
		v = np.linspace(0, 1/2*np.pi, reso)
		x = self.rx * np.outer(np.cos(u), np.sin(v))
		y = self.ry * np.outer(np.sin(u), np.sin(v))
		z = -self.rz * np.outer(np.ones(np.size(u)), np.cos(v))
		xyz = np.dstack((x, y, z))

#rotate & transfer organ
		self.xdeg = xdeg
		xrot = np.array([[1, 0, 0],
						[0, np.cos(xdeg), -1*np.sin(xdeg)],
						[0, np.sin(xdeg), np.cos(xdeg)]])
		self.zdeg = zdeg
		zrot = np.array([[np.cos(zdeg), -1*np.sin(zdeg), 0],
						[np.sin(zdeg), np.cos(zdeg), 0],
						[0, 0, 1]])

		for i in range(reso):
			for j in range(reso):
				xyz[i,j,:] = np.dot(xrot, xyz[i,j,:].T)
				xyz[i,j,:] = xyz[i,j,:] + [0, self.ry * np.cos(xdeg) + db, self.ry * np.sin(xdeg) + zpo]
				xyz[i,j,:] = np.dot(zrot, xyz[i,j,:].T)
				if record == True:
					csvWriter.writerow(xyz[i,j,:]) #record in csv

		self.col = col

##########################################################################################

#setting parameter of each organ

def orgforms(sx1 = 0.040*10, sx2 = 0.001*10, x0 = 10, xt = 2.0, txi = 20, sy1 = 0.020*35, sy2 = 0.004*35, y0= 35, yt = 12.0, tyi = 20):
#parameter to set size of ellipsoid

	rxs = np.linspace(0, n_organ-1, n_organ) # minor length
	rxs[0:txi] = x0 - sx1 * rxs[0:txi] # x = x0 - ai and  a = x0*dx1
	rxs[txi:n_organ] = xt - sx2 * (rxs[txi:n_organ] - txi) # x = xt - b(i-tx) and b = x0*dx2 and tx = txi-1
	rxs[rxs < 0.] = 0. #0以下には小さくならない
    
	rys = np.linspace(0, n_organ-1, n_organ) # major length
	rys[0:tyi] = y0 - sy1 * rys[0:tyi] # y = y0 - ai and  a = y0*dy1
	rys[tyi:n_organ] = yt - sy2 * (rys[tyi:n_organ] - tyi) # y = yt - b(i-ty) and b = y0*dy2 and ty = tyi-1
	rys[rys < 0.] = 0. #0以下には小さくならない
    
	#the point finishing transition
	tmax = max([txi, tyi]) 

	#organs swell
	rzs = np.zeros(n_organ)
	for i in range(n_organ):
		if i < tmax:
			rzs[i] = 0 #mode1
		else:
			rzs[i] = 0 #mode2

	return (rxs, rys, tmax, rzs)

####################################################################
#parameter to elevate each organ

def orgposi(pitch = -0.01):

#parameter to rotate each organ along z-axis
	zdegs = np.zeros(n_organ)
	zdegs[0] = 0
	zdegs[1] = np.pi
	zdegs[2] = np.pi * 3/2
	zdegs[3] = np.pi * 1/2
	for i in range(4, n_organ):
		zdegs[i] = zdegs[i - 1] + 137.5/180 *  np.pi

# height where each organ is put 
	zpos = np.zeros(n_organ)
	dzps = np.exp(pitch * zdegs)
	zpos[0] = 0
	zpos[1] = 0
	zpos[2] = 0
	zpos[3] = 0
	for i in range (1, n_organ):
		zpos[i] = zpos[i-1] + dzps[i]
	zpos = zpos/max(zpos) * hb

	return (zdegs, zpos)

########################################################################

def elevangle(max_ang = np.pi / 4, min_ang = np.pi / 4):

	xdegs = np.zeros(n_organ)
	xdegs[0:4] = min_ang
	for i in range(4, n_organ):
		if i < tmax:
			xdegs[i] = xdegs[i - 1] + (max_ang - min_ang) / (tmax-4)
		else:
			xdegs[i] = 90/180 * np.pi

	return xdegs
##########################################################################################
#setting

n_organ = 100
reso = 90

db = 10 #half of Base' s Diameter
hb = 5 #Height of Base
bu = np.linspace(0, 2 * np.pi, reso)

#upper part of base
bux = np.outer(db * np.cos(bu), np.ones(np.size(bu)))
buy = np.outer(db * np.sin(bu), np.ones(np.size(bu)))
buz = np.outer(np.ones(np.size(bu)), np.linspace(0, hb, reso))

#uppermost part of base
upp = Circle((0, 0), db, color = "red")

#basal part of base
bv = np.linspace(0, 1/2*np.pi, reso)
bbx = -db * np.outer(np.cos(bu), np.sin(bv))
bby = -db * np.outer(np.sin(bu), np.sin(bv))
bbz = -db * np.outer(np.ones(np.size(bu)), np.cos(bv))

##########################################################################################

#csv file
#Trueでファイルに書き出し
os.chdir('D:/theoretical_waterlily_data/csv/x0-y0_var') #データが大きいのでハードディスクに保管
record = True
namehead = "nympha-ell_x0-y0_var_20190106"

for curr_x0 in range(5, 101, 5):
    for curr_y0 in range(5, 101, 5):
        namebody = '_' + str(int(curr_x0)).zfill(3) + '-' + str(int(curr_y0)).zfill(3)
        
        if record == True:
            csv_coo = open(namehead + namebody + '.csv', 'x', newline='')
            csvWriter = csv.writer(csv_coo)
            for i in range(reso):
                for j in range(reso):
                    csvWriter.writerow([bux[i,j], buy[i,j], buz[i,j]])
                    csvWriter.writerow([bbx[i,j], bby[i,j], bbz[i,j]])
                
        #draw each organ
        rxs, rys, tmax, rzs = orgforms(x0 = curr_x0, y0 = curr_y0)
        zdegs, zpos = orgposi()
        xdegs = elevangle() 

        for n in range(n_organ):
            rx = rxs[n]
            ry = rys[n]
            rz = rzs[n]
            xdeg = xdegs[n]
            zdeg = zdegs[n]
            zpo = zpos[n]
            col = "red"
            organ = Organ(rx, ry, rz, xdeg, zdeg, zpo, hb, col, reso)
       
        if record == True:
            csv_coo.close()
            print(namehead + namebody + '.csv finished')

print("completed")
# Out:
# nympha-ell_x0-y0_var_20190106_005-005.csv finished
# nympha-ell_x0-y0_var_20190106_005-010.csv finished
# nympha-ell_x0-y0_var_20190106_005-015.csv finished
# nympha-ell_x0-y0_var_20190106_005-020.csv finished
# nympha-ell_x0-y0_var_20190106_005-025.csv finished
# nympha-ell_x0-y0_var_20190106_005-030.csv finished
# nympha-ell_x0-y0_var_20190106_005-035.csv finished
# nympha-ell_x0-y0_var_20190106_005-040.csv finished
# nympha-ell_x0-y0_var_20190106_005-045.csv finished
# nympha-ell_x0-y0_var_20190106_005-050.csv finished
# nympha-ell_x0-y0_var_20190106_005-055.csv finished
# nympha-ell_x0-y0_var_20190106_005-060.csv finished
# nympha-ell_x0-y0_var_20190106_005-065.csv finished
# nympha-ell_x0-y0_var_20190106_005-070.csv finished
# nympha-ell_x0-y0_var_20190106_005-075.csv finished
# nympha-ell_x0-y0_var_20190106_005-080.csv finished
# nympha-ell_x0-y0_var_20190106_005-085.csv finished
# nympha-ell_x0-y0_var_20190106_005-090.csv finished
# nympha-ell_x0-y0_var_20190106_005-095.csv finished
# nympha-ell_x0-y0_var_20190106_005-100.csv finished
# nympha-ell_x0-y0_var_20190106_010-005.csv finished
# nympha-ell_x0-y0_var_20190106_010-010.csv finished
# nympha-ell_x0-y0_var_20190106_010-015.csv finished
# nympha-ell_x0-y0_var_20190106_010-020.csv finished
# nympha-ell_x0-y0_var_20190106_010-025.csv finished
# nympha-ell_x0-y0_var_20190106_010-030.csv finished
# nympha-ell_x0-y0_var_20190106_010-035.csv finished
# nympha-ell_x0-y0_var_20190106_010-040.csv finished
# nympha-ell_x0-y0_var_20190106_010-045.csv finished
# nympha-ell_x0-y0_var_20190106_010-050.csv finished
# nympha-ell_x0-y0_var_20190106_010-055.csv finished
# nympha-ell_x0-y0_var_20190106_010-060.csv finished
# nympha-ell_x0-y0_var_20190106_010-065.csv finished
# nympha-ell_x0-y0_var_20190106_010-070.csv finished
# nympha-ell_x0-y0_var_20190106_010-075.csv finished
# nympha-ell_x0-y0_var_20190106_010-080.csv finished
# nympha-ell_x0-y0_var_20190106_010-085.csv finished
# nympha-ell_x0-y0_var_20190106_010-090.csv finished
# nympha-ell_x0-y0_var_20190106_010-095.csv finished
# nympha-ell_x0-y0_var_20190106_010-100.csv finished
# nympha-ell_x0-y0_var_20190106_015-005.csv finished
# nympha-ell_x0-y0_var_20190106_015-010.csv finished
# nympha-ell_x0-y0_var_20190106_015-015.csv finished
# nympha-ell_x0-y0_var_20190106_015-020.csv finished
# nympha-ell_x0-y0_var_20190106_015-025.csv finished
# nympha-ell_x0-y0_var_20190106_015-030.csv finished
# nympha-ell_x0-y0_var_20190106_015-035.csv finished
# nympha-ell_x0-y0_var_20190106_015-040.csv finished
# nympha-ell_x0-y0_var_20190106_015-045.csv finished
# nympha-ell_x0-y0_var_20190106_015-050.csv finished
# nympha-ell_x0-y0_var_20190106_015-055.csv finished
# nympha-ell_x0-y0_var_20190106_015-060.csv finished
# nympha-ell_x0-y0_var_20190106_015-065.csv finished
# nympha-ell_x0-y0_var_20190106_015-070.csv finished
# nympha-ell_x0-y0_var_20190106_015-075.csv finished
# nympha-ell_x0-y0_var_20190106_015-080.csv finished
# nympha-ell_x0-y0_var_20190106_015-085.csv finished
# nympha-ell_x0-y0_var_20190106_015-090.csv finished
# nympha-ell_x0-y0_var_20190106_015-095.csv finished
# nympha-ell_x0-y0_var_20190106_015-100.csv finished
# nympha-ell_x0-y0_var_20190106_020-005.csv finished
# nympha-ell_x0-y0_var_20190106_020-010.csv finished
# nympha-ell_x0-y0_var_20190106_020-015.csv finished
# nympha-ell_x0-y0_var_20190106_020-020.csv finished
# nympha-ell_x0-y0_var_20190106_020-025.csv finished
# nympha-ell_x0-y0_var_20190106_020-030.csv finished
# nympha-ell_x0-y0_var_20190106_020-035.csv finished
# nympha-ell_x0-y0_var_20190106_020-040.csv finished
# nympha-ell_x0-y0_var_20190106_020-045.csv finished
# nympha-ell_x0-y0_var_20190106_020-050.csv finished
# nympha-ell_x0-y0_var_20190106_020-055.csv finished
# nympha-ell_x0-y0_var_20190106_020-060.csv finished
# nympha-ell_x0-y0_var_20190106_020-065.csv finished
# nympha-ell_x0-y0_var_20190106_020-070.csv finished
# nympha-ell_x0-y0_var_20190106_020-075.csv finished
# nympha-ell_x0-y0_var_20190106_020-080.csv finished
# nympha-ell_x0-y0_var_20190106_020-085.csv finished
# nympha-ell_x0-y0_var_20190106_020-090.csv finished
# nympha-ell_x0-y0_var_20190106_020-095.csv finished
# nympha-ell_x0-y0_var_20190106_020-100.csv finished
# nympha-ell_x0-y0_var_20190106_025-005.csv finished
# nympha-ell_x0-y0_var_20190106_025-010.csv finished
# nympha-ell_x0-y0_var_20190106_025-015.csv finished
# nympha-ell_x0-y0_var_20190106_025-020.csv finished
# nympha-ell_x0-y0_var_20190106_025-025.csv finished
# nympha-ell_x0-y0_var_20190106_025-030.csv finished
# nympha-ell_x0-y0_var_20190106_025-035.csv finished
# nympha-ell_x0-y0_var_20190106_025-040.csv finished
# nympha-ell_x0-y0_var_20190106_025-045.csv finished
# nympha-ell_x0-y0_var_20190106_025-050.csv finished
# nympha-ell_x0-y0_var_20190106_025-055.csv finished
# nympha-ell_x0-y0_var_20190106_025-060.csv finished
# nympha-ell_x0-y0_var_20190106_025-065.csv finished
# nympha-ell_x0-y0_var_20190106_025-070.csv finished
# nympha-ell_x0-y0_var_20190106_025-075.csv finished
# nympha-ell_x0-y0_var_20190106_025-080.csv finished
# nympha-ell_x0-y0_var_20190106_025-085.csv finished
# nympha-ell_x0-y0_var_20190106_025-090.csv finished
# nympha-ell_x0-y0_var_20190106_025-095.csv finished
# nympha-ell_x0-y0_var_20190106_025-100.csv finished
# nympha-ell_x0-y0_var_20190106_030-005.csv finished
# nympha-ell_x0-y0_var_20190106_030-010.csv finished
# nympha-ell_x0-y0_var_20190106_030-015.csv finished
# nympha-ell_x0-y0_var_20190106_030-020.csv finished
# nympha-ell_x0-y0_var_20190106_030-025.csv finished
# nympha-ell_x0-y0_var_20190106_030-030.csv finished
# nympha-ell_x0-y0_var_20190106_030-035.csv finished
# nympha-ell_x0-y0_var_20190106_030-040.csv finished
# nympha-ell_x0-y0_var_20190106_030-045.csv finished
# nympha-ell_x0-y0_var_20190106_030-050.csv finished
# nympha-ell_x0-y0_var_20190106_030-055.csv finished
# nympha-ell_x0-y0_var_20190106_030-060.csv finished
# nympha-ell_x0-y0_var_20190106_030-065.csv finished
# nympha-ell_x0-y0_var_20190106_030-070.csv finished
# nympha-ell_x0-y0_var_20190106_030-075.csv finished
# nympha-ell_x0-y0_var_20190106_030-080.csv finished
# nympha-ell_x0-y0_var_20190106_030-085.csv finished
# nympha-ell_x0-y0_var_20190106_030-090.csv finished
# nympha-ell_x0-y0_var_20190106_030-095.csv finished
# nympha-ell_x0-y0_var_20190106_030-100.csv finished
# nympha-ell_x0-y0_var_20190106_035-005.csv finished
# nympha-ell_x0-y0_var_20190106_035-010.csv finished
# nympha-ell_x0-y0_var_20190106_035-015.csv finished
# nympha-ell_x0-y0_var_20190106_035-020.csv finished
# nympha-ell_x0-y0_var_20190106_035-025.csv finished
# nympha-ell_x0-y0_var_20190106_035-030.csv finished
# nympha-ell_x0-y0_var_20190106_035-035.csv finished
# nympha-ell_x0-y0_var_20190106_035-040.csv finished
# nympha-ell_x0-y0_var_20190106_035-045.csv finished
# nympha-ell_x0-y0_var_20190106_035-050.csv finished
# nympha-ell_x0-y0_var_20190106_035-055.csv finished
# nympha-ell_x0-y0_var_20190106_035-060.csv finished
# nympha-ell_x0-y0_var_20190106_035-065.csv finished
# nympha-ell_x0-y0_var_20190106_035-070.csv finished
# nympha-ell_x0-y0_var_20190106_035-075.csv finished
# nympha-ell_x0-y0_var_20190106_035-080.csv finished
# nympha-ell_x0-y0_var_20190106_035-085.csv finished
# nympha-ell_x0-y0_var_20190106_035-090.csv finished
# nympha-ell_x0-y0_var_20190106_035-095.csv finished
# nympha-ell_x0-y0_var_20190106_035-100.csv finished
# nympha-ell_x0-y0_var_20190106_040-005.csv finished
# nympha-ell_x0-y0_var_20190106_040-010.csv finished
# nympha-ell_x0-y0_var_20190106_040-015.csv finished
# nympha-ell_x0-y0_var_20190106_040-020.csv finished
# nympha-ell_x0-y0_var_20190106_040-025.csv finished
# nympha-ell_x0-y0_var_20190106_040-030.csv finished
# nympha-ell_x0-y0_var_20190106_040-035.csv finished
# nympha-ell_x0-y0_var_20190106_040-040.csv finished
# nympha-ell_x0-y0_var_20190106_040-045.csv finished
# nympha-ell_x0-y0_var_20190106_040-050.csv finished
# nympha-ell_x0-y0_var_20190106_040-055.csv finished
# nympha-ell_x0-y0_var_20190106_040-060.csv finished
# nympha-ell_x0-y0_var_20190106_040-065.csv finished
# nympha-ell_x0-y0_var_20190106_040-070.csv finished
# nympha-ell_x0-y0_var_20190106_040-075.csv finished
# nympha-ell_x0-y0_var_20190106_040-080.csv finished
# nympha-ell_x0-y0_var_20190106_040-085.csv finished
# nympha-ell_x0-y0_var_20190106_040-090.csv finished
# nympha-ell_x0-y0_var_20190106_040-095.csv finished
# nympha-ell_x0-y0_var_20190106_040-100.csv finished
# nympha-ell_x0-y0_var_20190106_045-005.csv finished
# nympha-ell_x0-y0_var_20190106_045-010.csv finished
# nympha-ell_x0-y0_var_20190106_045-015.csv finished
# nympha-ell_x0-y0_var_20190106_045-020.csv finished
# nympha-ell_x0-y0_var_20190106_045-025.csv finished
# nympha-ell_x0-y0_var_20190106_045-030.csv finished
# nympha-ell_x0-y0_var_20190106_045-035.csv finished
# nympha-ell_x0-y0_var_20190106_045-040.csv finished
# nympha-ell_x0-y0_var_20190106_045-045.csv finished
# nympha-ell_x0-y0_var_20190106_045-050.csv finished
# nympha-ell_x0-y0_var_20190106_045-055.csv finished
# nympha-ell_x0-y0_var_20190106_045-060.csv finished
# nympha-ell_x0-y0_var_20190106_045-065.csv finished
# nympha-ell_x0-y0_var_20190106_045-070.csv finished
# nympha-ell_x0-y0_var_20190106_045-075.csv finished
# nympha-ell_x0-y0_var_20190106_045-080.csv finished
# nympha-ell_x0-y0_var_20190106_045-085.csv finished
# nympha-ell_x0-y0_var_20190106_045-090.csv finished
# nympha-ell_x0-y0_var_20190106_045-095.csv finished
# nympha-ell_x0-y0_var_20190106_045-100.csv finished
# nympha-ell_x0-y0_var_20190106_050-005.csv finished
# nympha-ell_x0-y0_var_20190106_050-010.csv finished
# nympha-ell_x0-y0_var_20190106_050-015.csv finished
# nympha-ell_x0-y0_var_20190106_050-020.csv finished
# nympha-ell_x0-y0_var_20190106_050-025.csv finished
# nympha-ell_x0-y0_var_20190106_050-030.csv finished
# nympha-ell_x0-y0_var_20190106_050-035.csv finished
# nympha-ell_x0-y0_var_20190106_050-040.csv finished
# nympha-ell_x0-y0_var_20190106_050-045.csv finished
# nympha-ell_x0-y0_var_20190106_050-050.csv finished
# nympha-ell_x0-y0_var_20190106_050-055.csv finished
# nympha-ell_x0-y0_var_20190106_050-060.csv finished
# nympha-ell_x0-y0_var_20190106_050-065.csv finished
# nympha-ell_x0-y0_var_20190106_050-070.csv finished
# nympha-ell_x0-y0_var_20190106_050-075.csv finished
# nympha-ell_x0-y0_var_20190106_050-080.csv finished
# nympha-ell_x0-y0_var_20190106_050-085.csv finished
# nympha-ell_x0-y0_var_20190106_050-090.csv finished
# nympha-ell_x0-y0_var_20190106_050-095.csv finished
# nympha-ell_x0-y0_var_20190106_050-100.csv finished
# nympha-ell_x0-y0_var_20190106_055-005.csv finished
# nympha-ell_x0-y0_var_20190106_055-010.csv finished
# nympha-ell_x0-y0_var_20190106_055-015.csv finished
# nympha-ell_x0-y0_var_20190106_055-020.csv finished
# nympha-ell_x0-y0_var_20190106_055-025.csv finished
# nympha-ell_x0-y0_var_20190106_055-030.csv finished
# nympha-ell_x0-y0_var_20190106_055-035.csv finished
# nympha-ell_x0-y0_var_20190106_055-040.csv finished
# nympha-ell_x0-y0_var_20190106_055-045.csv finished
# nympha-ell_x0-y0_var_20190106_055-050.csv finished
# nympha-ell_x0-y0_var_20190106_055-055.csv finished
# nympha-ell_x0-y0_var_20190106_055-060.csv finished
# nympha-ell_x0-y0_var_20190106_055-065.csv finished
# nympha-ell_x0-y0_var_20190106_055-070.csv finished
# nympha-ell_x0-y0_var_20190106_055-075.csv finished
# nympha-ell_x0-y0_var_20190106_055-080.csv finished
# nympha-ell_x0-y0_var_20190106_055-085.csv finished
# nympha-ell_x0-y0_var_20190106_055-090.csv finished
# nympha-ell_x0-y0_var_20190106_055-095.csv finished
# nympha-ell_x0-y0_var_20190106_055-100.csv finished
# nympha-ell_x0-y0_var_20190106_060-005.csv finished
# nympha-ell_x0-y0_var_20190106_060-010.csv finished
# nympha-ell_x0-y0_var_20190106_060-015.csv finished
# nympha-ell_x0-y0_var_20190106_060-020.csv finished
# nympha-ell_x0-y0_var_20190106_060-025.csv finished
# nympha-ell_x0-y0_var_20190106_060-030.csv finished
# nympha-ell_x0-y0_var_20190106_060-035.csv finished
# nympha-ell_x0-y0_var_20190106_060-040.csv finished
# nympha-ell_x0-y0_var_20190106_060-045.csv finished
# nympha-ell_x0-y0_var_20190106_060-050.csv finished
# nympha-ell_x0-y0_var_20190106_060-055.csv finished
# nympha-ell_x0-y0_var_20190106_060-060.csv finished
# nympha-ell_x0-y0_var_20190106_060-065.csv finished
# nympha-ell_x0-y0_var_20190106_060-070.csv finished
# nympha-ell_x0-y0_var_20190106_060-075.csv finished
# nympha-ell_x0-y0_var_20190106_060-080.csv finished
# nympha-ell_x0-y0_var_20190106_060-085.csv finished
# nympha-ell_x0-y0_var_20190106_060-090.csv finished
# nympha-ell_x0-y0_var_20190106_060-095.csv finished
# nympha-ell_x0-y0_var_20190106_060-100.csv finished
# nympha-ell_x0-y0_var_20190106_065-005.csv finished
# nympha-ell_x0-y0_var_20190106_065-010.csv finished
# nympha-ell_x0-y0_var_20190106_065-015.csv finished
# nympha-ell_x0-y0_var_20190106_065-020.csv finished
# nympha-ell_x0-y0_var_20190106_065-025.csv finished
# nympha-ell_x0-y0_var_20190106_065-030.csv finished
# nympha-ell_x0-y0_var_20190106_065-035.csv finished
# nympha-ell_x0-y0_var_20190106_065-040.csv finished
# nympha-ell_x0-y0_var_20190106_065-045.csv finished
# nympha-ell_x0-y0_var_20190106_065-050.csv finished
# nympha-ell_x0-y0_var_20190106_065-055.csv finished
# nympha-ell_x0-y0_var_20190106_065-060.csv finished
# nympha-ell_x0-y0_var_20190106_065-065.csv finished
# nympha-ell_x0-y0_var_20190106_065-070.csv finished
# nympha-ell_x0-y0_var_20190106_065-075.csv finished
# nympha-ell_x0-y0_var_20190106_065-080.csv finished
# nympha-ell_x0-y0_var_20190106_065-085.csv finished
# nympha-ell_x0-y0_var_20190106_065-090.csv finished
# nympha-ell_x0-y0_var_20190106_065-095.csv finished
# nympha-ell_x0-y0_var_20190106_065-100.csv finished
# nympha-ell_x0-y0_var_20190106_070-005.csv finished
# nympha-ell_x0-y0_var_20190106_070-010.csv finished
# nympha-ell_x0-y0_var_20190106_070-015.csv finished
# nympha-ell_x0-y0_var_20190106_070-020.csv finished
# nympha-ell_x0-y0_var_20190106_070-025.csv finished
# nympha-ell_x0-y0_var_20190106_070-030.csv finished
# nympha-ell_x0-y0_var_20190106_070-035.csv finished
# nympha-ell_x0-y0_var_20190106_070-040.csv finished
# nympha-ell_x0-y0_var_20190106_070-045.csv finished
# nympha-ell_x0-y0_var_20190106_070-050.csv finished
# nympha-ell_x0-y0_var_20190106_070-055.csv finished
# nympha-ell_x0-y0_var_20190106_070-060.csv finished
# nympha-ell_x0-y0_var_20190106_070-065.csv finished
# nympha-ell_x0-y0_var_20190106_070-070.csv finished
# nympha-ell_x0-y0_var_20190106_070-075.csv finished
# nympha-ell_x0-y0_var_20190106_070-080.csv finished
# nympha-ell_x0-y0_var_20190106_070-085.csv finished
# nympha-ell_x0-y0_var_20190106_070-090.csv finished
# nympha-ell_x0-y0_var_20190106_070-095.csv finished
# nympha-ell_x0-y0_var_20190106_070-100.csv finished
# nympha-ell_x0-y0_var_20190106_075-005.csv finished
# nympha-ell_x0-y0_var_20190106_075-010.csv finished
# nympha-ell_x0-y0_var_20190106_075-015.csv finished
# nympha-ell_x0-y0_var_20190106_075-020.csv finished
# nympha-ell_x0-y0_var_20190106_075-025.csv finished
# nympha-ell_x0-y0_var_20190106_075-030.csv finished
# nympha-ell_x0-y0_var_20190106_075-035.csv finished
# nympha-ell_x0-y0_var_20190106_075-040.csv finished
# nympha-ell_x0-y0_var_20190106_075-045.csv finished
# nympha-ell_x0-y0_var_20190106_075-050.csv finished
# nympha-ell_x0-y0_var_20190106_075-055.csv finished
# nympha-ell_x0-y0_var_20190106_075-060.csv finished
# nympha-ell_x0-y0_var_20190106_075-065.csv finished
# nympha-ell_x0-y0_var_20190106_075-070.csv finished
# nympha-ell_x0-y0_var_20190106_075-075.csv finished
# nympha-ell_x0-y0_var_20190106_075-080.csv finished
# nympha-ell_x0-y0_var_20190106_075-085.csv finished
# nympha-ell_x0-y0_var_20190106_075-090.csv finished
# nympha-ell_x0-y0_var_20190106_075-095.csv finished
# nympha-ell_x0-y0_var_20190106_075-100.csv finished
# nympha-ell_x0-y0_var_20190106_080-005.csv finished
# nympha-ell_x0-y0_var_20190106_080-010.csv finished
# nympha-ell_x0-y0_var_20190106_080-015.csv finished
# nympha-ell_x0-y0_var_20190106_080-020.csv finished
# nympha-ell_x0-y0_var_20190106_080-025.csv finished
# nympha-ell_x0-y0_var_20190106_080-030.csv finished
# nympha-ell_x0-y0_var_20190106_080-035.csv finished
# nympha-ell_x0-y0_var_20190106_080-040.csv finished
# nympha-ell_x0-y0_var_20190106_080-045.csv finished
# nympha-ell_x0-y0_var_20190106_080-050.csv finished
# nympha-ell_x0-y0_var_20190106_080-055.csv finished
# nympha-ell_x0-y0_var_20190106_080-060.csv finished
# nympha-ell_x0-y0_var_20190106_080-065.csv finished
# nympha-ell_x0-y0_var_20190106_080-070.csv finished
# nympha-ell_x0-y0_var_20190106_080-075.csv finished
# nympha-ell_x0-y0_var_20190106_080-080.csv finished
# nympha-ell_x0-y0_var_20190106_080-085.csv finished
# nympha-ell_x0-y0_var_20190106_080-090.csv finished
# nympha-ell_x0-y0_var_20190106_080-095.csv finished
# nympha-ell_x0-y0_var_20190106_080-100.csv finished
# nympha-ell_x0-y0_var_20190106_085-005.csv finished
# nympha-ell_x0-y0_var_20190106_085-010.csv finished
# nympha-ell_x0-y0_var_20190106_085-015.csv finished
# nympha-ell_x0-y0_var_20190106_085-020.csv finished
# nympha-ell_x0-y0_var_20190106_085-025.csv finished
# nympha-ell_x0-y0_var_20190106_085-030.csv finished
# nympha-ell_x0-y0_var_20190106_085-035.csv finished
# nympha-ell_x0-y0_var_20190106_085-040.csv finished
# nympha-ell_x0-y0_var_20190106_085-045.csv finished
# nympha-ell_x0-y0_var_20190106_085-050.csv finished
# nympha-ell_x0-y0_var_20190106_085-055.csv finished
# nympha-ell_x0-y0_var_20190106_085-060.csv finished
# nympha-ell_x0-y0_var_20190106_085-065.csv finished
# nympha-ell_x0-y0_var_20190106_085-070.csv finished
# nympha-ell_x0-y0_var_20190106_085-075.csv finished
# nympha-ell_x0-y0_var_20190106_085-080.csv finished
# nympha-ell_x0-y0_var_20190106_085-085.csv finished
# nympha-ell_x0-y0_var_20190106_085-090.csv finished
# nympha-ell_x0-y0_var_20190106_085-095.csv finished
# nympha-ell_x0-y0_var_20190106_085-100.csv finished
# nympha-ell_x0-y0_var_20190106_090-005.csv finished
# nympha-ell_x0-y0_var_20190106_090-010.csv finished
# nympha-ell_x0-y0_var_20190106_090-015.csv finished
# nympha-ell_x0-y0_var_20190106_090-020.csv finished
# nympha-ell_x0-y0_var_20190106_090-025.csv finished
# nympha-ell_x0-y0_var_20190106_090-030.csv finished
# nympha-ell_x0-y0_var_20190106_090-035.csv finished
# nympha-ell_x0-y0_var_20190106_090-040.csv finished
# nympha-ell_x0-y0_var_20190106_090-045.csv finished
# nympha-ell_x0-y0_var_20190106_090-050.csv finished
# nympha-ell_x0-y0_var_20190106_090-055.csv finished
# nympha-ell_x0-y0_var_20190106_090-060.csv finished
# nympha-ell_x0-y0_var_20190106_090-065.csv finished
# nympha-ell_x0-y0_var_20190106_090-070.csv finished
# nympha-ell_x0-y0_var_20190106_090-075.csv finished
# nympha-ell_x0-y0_var_20190106_090-080.csv finished
# nympha-ell_x0-y0_var_20190106_090-085.csv finished
# nympha-ell_x0-y0_var_20190106_090-090.csv finished
# nympha-ell_x0-y0_var_20190106_090-095.csv finished
# nympha-ell_x0-y0_var_20190106_090-100.csv finished
# nympha-ell_x0-y0_var_20190106_095-005.csv finished
# nympha-ell_x0-y0_var_20190106_095-010.csv finished
# nympha-ell_x0-y0_var_20190106_095-015.csv finished
# nympha-ell_x0-y0_var_20190106_095-020.csv finished
# nympha-ell_x0-y0_var_20190106_095-025.csv finished
# nympha-ell_x0-y0_var_20190106_095-030.csv finished
# nympha-ell_x0-y0_var_20190106_095-035.csv finished
# nympha-ell_x0-y0_var_20190106_095-040.csv finished
# nympha-ell_x0-y0_var_20190106_095-045.csv finished
# nympha-ell_x0-y0_var_20190106_095-050.csv finished
# nympha-ell_x0-y0_var_20190106_095-055.csv finished
# nympha-ell_x0-y0_var_20190106_095-060.csv finished
# nympha-ell_x0-y0_var_20190106_095-065.csv finished
# nympha-ell_x0-y0_var_20190106_095-070.csv finished
# nympha-ell_x0-y0_var_20190106_095-075.csv finished
# nympha-ell_x0-y0_var_20190106_095-080.csv finished
# nympha-ell_x0-y0_var_20190106_095-085.csv finished
# nympha-ell_x0-y0_var_20190106_095-090.csv finished
# nympha-ell_x0-y0_var_20190106_095-095.csv finished
# nympha-ell_x0-y0_var_20190106_095-100.csv finished
# nympha-ell_x0-y0_var_20190106_100-005.csv finished
# nympha-ell_x0-y0_var_20190106_100-010.csv finished
# nympha-ell_x0-y0_var_20190106_100-015.csv finished
# nympha-ell_x0-y0_var_20190106_100-020.csv finished
# nympha-ell_x0-y0_var_20190106_100-025.csv finished
# nympha-ell_x0-y0_var_20190106_100-030.csv finished
# nympha-ell_x0-y0_var_20190106_100-035.csv finished
# nympha-ell_x0-y0_var_20190106_100-040.csv finished
# nympha-ell_x0-y0_var_20190106_100-045.csv finished
# nympha-ell_x0-y0_var_20190106_100-050.csv finished
# nympha-ell_x0-y0_var_20190106_100-055.csv finished
# nympha-ell_x0-y0_var_20190106_100-060.csv finished
# nympha-ell_x0-y0_var_20190106_100-065.csv finished
# nympha-ell_x0-y0_var_20190106_100-070.csv finished
# nympha-ell_x0-y0_var_20190106_100-075.csv finished
# nympha-ell_x0-y0_var_20190106_100-080.csv finished
# nympha-ell_x0-y0_var_20190106_100-085.csv finished
# nympha-ell_x0-y0_var_20190106_100-090.csv finished
# nympha-ell_x0-y0_var_20190106_100-095.csv finished
# nympha-ell_x0-y0_var_20190106_100-100.csv finished
# completed
