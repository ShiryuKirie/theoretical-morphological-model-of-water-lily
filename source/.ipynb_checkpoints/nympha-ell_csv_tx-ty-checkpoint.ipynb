# %%
'''
===========================
nympha_ellipse
===========================

Demonstrates a flower of nymphaea as 3D surface(ellipsoid) objects.

'''

from mpl_toolkits.mplot3d import Axes3D
from matplotlib.patches import Circle
import mpl_toolkits.mplot3d.art3d as art3d
import matplotlib.pyplot as plt
import numpy as np
import csv
import os

# setting organ
class Organ :
	def __init__(self, rx, ry, rz, xdeg, zdeg, zpo, hb, col, reso):

		self.rx = rx #minor length
		self.ry = ry #major length
		self.rz = rz 

		self.reso = reso #surfaces resolution

#organ's shape as ellipsoid surface
		u = np.linspace(0, 2 * np.pi, reso)
		v = np.linspace(0, 1/2*np.pi, reso)
		x = self.rx * np.outer(np.cos(u), np.sin(v))
		y = self.ry * np.outer(np.sin(u), np.sin(v))
		z = -self.rz * np.outer(np.ones(np.size(u)), np.cos(v))
		xyz = np.dstack((x, y, z))

#rotate & transfer organ
		self.xdeg = xdeg
		xrot = np.array([[1, 0, 0],
						[0, np.cos(xdeg), -1*np.sin(xdeg)],
						[0, np.sin(xdeg), np.cos(xdeg)]])
		self.zdeg = zdeg
		zrot = np.array([[np.cos(zdeg), -1*np.sin(zdeg), 0],
						[np.sin(zdeg), np.cos(zdeg), 0],
						[0, 0, 1]])

		for i in range(reso):
			for j in range(reso):
				xyz[i,j,:] = np.dot(xrot, xyz[i,j,:].T)
				xyz[i,j,:] = xyz[i,j,:] + [0, self.ry * np.cos(xdeg) + db, self.ry * np.sin(xdeg) + zpo]
				xyz[i,j,:] = np.dot(zrot, xyz[i,j,:].T)
				if record == True:
					csvWriter.writerow(xyz[i,j,:]) #record in csv

		self.col = col

##########################################################################################

#setting parameter of each organ

def orgforms(dx1 = 0.040, dx2 = 0.001, x0 = 10, xt = 2.0, txi = 20, dy1 = 0.020, dy2 = 0.004, y0= 35, yt = 12.0, tyi = 20):
#parameter to set size of ellipsoid

	rxs = np.linspace(0, n_organ-1, n_organ) # minor length
	rxs[0:txi] = x0 - x0 * dx1 * rxs[0:txi] # x = x0 - ai and  a = x0*dx1
	rxs[txi:n_organ] = xt - x0 * dx2 * (rxs[txi:n_organ] - txi) # x = xt - b(i-tx) and b = x0*dx2 and tx = txi-1
    
	rys = np.linspace(0, n_organ-1, n_organ) # major length
	rys[0:tyi] = y0 - y0 * dy1 * rys[0:tyi] # y = y0 - ai and  a = y0*dy1
	rys[tyi:n_organ] = yt - y0 * dy2 * (rys[tyi:n_organ] - tyi) # y = yt - b(i-ty) and b = y0*dy2 and ty = tyi-1

	#the point finishing transition
	tmax = max([txi, tyi]) 

	#organs swell
	rzs = np.zeros(n_organ)
	for i in range(n_organ):
		if i < tmax:
			rzs[i] = 0 #mode1
		else:
			rzs[i] = 0 #mode2

	return (rxs, rys, tmax, rzs)


####################################################################
#parameter to elevate each organ

def orgposi(pitch = -0.01):

#parameter to rotate each organ along z-axis
	zdegs = np.zeros(n_organ)
	zdegs[0] = 0
	zdegs[1] = np.pi
	zdegs[2] = np.pi * 3/2
	zdegs[3] = np.pi * 1/2
	for i in range(4, n_organ):
		zdegs[i] = zdegs[i - 1] + 137.5/180 *  np.pi

# height where each organ is put 
	zpos = np.zeros(n_organ)
	dzps = np.exp(pitch * zdegs)
	zpos[0] = 0
	zpos[1] = 0
	zpos[2] = 0
	zpos[3] = 0
	for i in range (1, n_organ):
		zpos[i] = zpos[i-1] + dzps[i]
	zpos = zpos/max(zpos) * hb

	return (zdegs, zpos)

########################################################################

def elevangle(max_ang = np.pi / 4, min_ang = np.pi / 4):

	xdegs = np.zeros(n_organ)
	xdegs[0:4] = min_ang
	for i in range(4, n_organ):
		if i < tmax:
			xdegs[i] = xdegs[i - 1] + (max_ang - min_ang) / (tmax-4)
		else:
			xdegs[i] = 90/180 * np.pi

	return xdegs
##########################################################################################
#setting

n_organ = 100
reso = 90

db = 10 #half of Base' s Diameter
hb = 5 #Height of Base
bu = np.linspace(0, 2 * np.pi, reso)

#upper part of base
bux = np.outer(db * np.cos(bu), np.ones(np.size(bu)))
buy = np.outer(db * np.sin(bu), np.ones(np.size(bu)))
buz = np.outer(np.ones(np.size(bu)), np.linspace(0, hb, reso))

#uppermost part of base
upp = Circle((0, 0), db, color = "red")

#basal part of base
bv = np.linspace(0, 1/2*np.pi, reso)
bbx = -db * np.outer(np.cos(bu), np.sin(bv))
bby = -db * np.outer(np.sin(bu), np.sin(bv))
bbz = -db * np.outer(np.ones(np.size(bu)), np.cos(bv))

##########################################################################################

#csv file
#True -> output into the file
dir = "here" # fill the output directory
os.chdir(dir)
record = True
namehead = "nympha-ell_tx-ty"

for curr_tx in range(0, 101, 5):
    for curr_ty in range(0, 101, 5):
        namebody = '_' + str(int(curr_tx)).zfill(3) + '-' + str(int(curr_ty)).zfill(3)
        
        if record == True:
            csv_coo = open(namehead + namebody + '.csv', 'x', newline='')
            csvWriter = csv.writer(csv_coo)
            for i in range(reso):
                for j in range(reso):
                        csvWriter.writerow([bux[i,j], buy[i,j], buz[i,j]])
                        csvWriter.writerow([bbx[i,j], bby[i,j], bbz[i,j]])
        
        #draw each organ 0の時の場合分けをする
        if curr_tx == 0:
            _dx1 = 0
        else:
            _dx1 = 0.040 * 20/(curr_tx)
        
        if curr_tx == 100:
            _dx2 = 0
        else:
            _dx2 = 0.001 * 80/(100-curr_tx)
        
        if curr_ty == 0:
            _dy1 = 0
        else:
            _dy1 = 0.020 * 20/(curr_ty)
        
        if curr_ty == 100:
            _dy2 = 0
        else:
            _dy2 = 0.004 * 80/(100-curr_ty)
        
        rxs, rys, tmax, rzs = orgforms(dx1 = _dx1, dx2 = _dx2, dy1 = _dy1, dy2 = _dy2, \
                                       txi = curr_tx, tyi = curr_ty)
        zdegs, zpos = orgposi()
        xdegs = elevangle() 

        for n in range(n_organ):
            rx = rxs[n]
            ry = rys[n]
            rz = rzs[n]
            xdeg = xdegs[n]
            zdeg = zdegs[n]
            zpo = zpos[n]
            col = "red"
            organ = Organ(rx, ry, rz, xdeg, zdeg, zpo, hb, col, reso)
       
        if record == True:
            csv_coo.close()
            print(namehead + namebody + '.csv finished')

print("completed")
# Out:
# nympha-ell_tx-ty_20180514_000-000.csv finished
# nympha-ell_tx-ty_20180514_000-005.csv finished
# nympha-ell_tx-ty_20180514_000-010.csv finished
# nympha-ell_tx-ty_20180514_000-015.csv finished
# nympha-ell_tx-ty_20180514_000-020.csv finished
# nympha-ell_tx-ty_20180514_000-025.csv finished
# nympha-ell_tx-ty_20180514_000-030.csv finished
# nympha-ell_tx-ty_20180514_000-035.csv finished
# nympha-ell_tx-ty_20180514_000-040.csv finished
# nympha-ell_tx-ty_20180514_000-045.csv finished
# nympha-ell_tx-ty_20180514_000-050.csv finished
# nympha-ell_tx-ty_20180514_000-055.csv finished
# nympha-ell_tx-ty_20180514_000-060.csv finished
# nympha-ell_tx-ty_20180514_000-065.csv finished
# nympha-ell_tx-ty_20180514_000-070.csv finished
# nympha-ell_tx-ty_20180514_000-075.csv finished
# nympha-ell_tx-ty_20180514_000-080.csv finished
# nympha-ell_tx-ty_20180514_000-085.csv finished
# nympha-ell_tx-ty_20180514_000-090.csv finished
# nympha-ell_tx-ty_20180514_000-095.csv finished
# nympha-ell_tx-ty_20180514_000-100.csv finished
# nympha-ell_tx-ty_20180514_005-000.csv finished
# nympha-ell_tx-ty_20180514_005-005.csv finished
# nympha-ell_tx-ty_20180514_005-010.csv finished
# nympha-ell_tx-ty_20180514_005-015.csv finished
# nympha-ell_tx-ty_20180514_005-020.csv finished
# nympha-ell_tx-ty_20180514_005-025.csv finished
# nympha-ell_tx-ty_20180514_005-030.csv finished
# nympha-ell_tx-ty_20180514_005-035.csv finished
# nympha-ell_tx-ty_20180514_005-040.csv finished
# nympha-ell_tx-ty_20180514_005-045.csv finished
# nympha-ell_tx-ty_20180514_005-050.csv finished
# nympha-ell_tx-ty_20180514_005-055.csv finished
# nympha-ell_tx-ty_20180514_005-060.csv finished
# nympha-ell_tx-ty_20180514_005-065.csv finished
# nympha-ell_tx-ty_20180514_005-070.csv finished
# nympha-ell_tx-ty_20180514_005-075.csv finished
# nympha-ell_tx-ty_20180514_005-080.csv finished
# nympha-ell_tx-ty_20180514_005-085.csv finished
# nympha-ell_tx-ty_20180514_005-090.csv finished
# nympha-ell_tx-ty_20180514_005-095.csv finished
# nympha-ell_tx-ty_20180514_005-100.csv finished
# nympha-ell_tx-ty_20180514_010-000.csv finished
# nympha-ell_tx-ty_20180514_010-005.csv finished
# nympha-ell_tx-ty_20180514_010-010.csv finished
# nympha-ell_tx-ty_20180514_010-015.csv finished
# nympha-ell_tx-ty_20180514_010-020.csv finished
# nympha-ell_tx-ty_20180514_010-025.csv finished
# nympha-ell_tx-ty_20180514_010-030.csv finished
# nympha-ell_tx-ty_20180514_010-035.csv finished
# nympha-ell_tx-ty_20180514_010-040.csv finished
# nympha-ell_tx-ty_20180514_010-045.csv finished
# nympha-ell_tx-ty_20180514_010-050.csv finished
# nympha-ell_tx-ty_20180514_010-055.csv finished
# nympha-ell_tx-ty_20180514_010-060.csv finished
# nympha-ell_tx-ty_20180514_010-065.csv finished
# nympha-ell_tx-ty_20180514_010-070.csv finished
# nympha-ell_tx-ty_20180514_010-075.csv finished
# nympha-ell_tx-ty_20180514_010-080.csv finished
# nympha-ell_tx-ty_20180514_010-085.csv finished
# nympha-ell_tx-ty_20180514_010-090.csv finished
# nympha-ell_tx-ty_20180514_010-095.csv finished
# nympha-ell_tx-ty_20180514_010-100.csv finished
# nympha-ell_tx-ty_20180514_015-000.csv finished
# nympha-ell_tx-ty_20180514_015-005.csv finished
# nympha-ell_tx-ty_20180514_015-010.csv finished
# nympha-ell_tx-ty_20180514_015-015.csv finished
# nympha-ell_tx-ty_20180514_015-020.csv finished
# nympha-ell_tx-ty_20180514_015-025.csv finished
# nympha-ell_tx-ty_20180514_015-030.csv finished
# nympha-ell_tx-ty_20180514_015-035.csv finished
# nympha-ell_tx-ty_20180514_015-040.csv finished
# nympha-ell_tx-ty_20180514_015-045.csv finished
# nympha-ell_tx-ty_20180514_015-050.csv finished
# nympha-ell_tx-ty_20180514_015-055.csv finished
# nympha-ell_tx-ty_20180514_015-060.csv finished
# nympha-ell_tx-ty_20180514_015-065.csv finished
# nympha-ell_tx-ty_20180514_015-070.csv finished
# nympha-ell_tx-ty_20180514_015-075.csv finished
# nympha-ell_tx-ty_20180514_015-080.csv finished
# nympha-ell_tx-ty_20180514_015-085.csv finished
# nympha-ell_tx-ty_20180514_015-090.csv finished
# nympha-ell_tx-ty_20180514_015-095.csv finished
# nympha-ell_tx-ty_20180514_015-100.csv finished
# nympha-ell_tx-ty_20180514_020-000.csv finished
# nympha-ell_tx-ty_20180514_020-005.csv finished
# nympha-ell_tx-ty_20180514_020-010.csv finished
# nympha-ell_tx-ty_20180514_020-015.csv finished
# nympha-ell_tx-ty_20180514_020-020.csv finished
# nympha-ell_tx-ty_20180514_020-025.csv finished
# nympha-ell_tx-ty_20180514_020-030.csv finished
# nympha-ell_tx-ty_20180514_020-035.csv finished
# nympha-ell_tx-ty_20180514_020-040.csv finished
# nympha-ell_tx-ty_20180514_020-045.csv finished
# nympha-ell_tx-ty_20180514_020-050.csv finished
# nympha-ell_tx-ty_20180514_020-055.csv finished
# nympha-ell_tx-ty_20180514_020-060.csv finished
# nympha-ell_tx-ty_20180514_020-065.csv finished
# nympha-ell_tx-ty_20180514_020-070.csv finished
# nympha-ell_tx-ty_20180514_020-075.csv finished
# nympha-ell_tx-ty_20180514_020-080.csv finished
# nympha-ell_tx-ty_20180514_020-085.csv finished
# nympha-ell_tx-ty_20180514_020-090.csv finished
# nympha-ell_tx-ty_20180514_020-095.csv finished
# nympha-ell_tx-ty_20180514_020-100.csv finished
# nympha-ell_tx-ty_20180514_025-000.csv finished
# nympha-ell_tx-ty_20180514_025-005.csv finished
# nympha-ell_tx-ty_20180514_025-010.csv finished
# nympha-ell_tx-ty_20180514_025-015.csv finished
# nympha-ell_tx-ty_20180514_025-020.csv finished
# nympha-ell_tx-ty_20180514_025-025.csv finished
# nympha-ell_tx-ty_20180514_025-030.csv finished
# nympha-ell_tx-ty_20180514_025-035.csv finished
# nympha-ell_tx-ty_20180514_025-040.csv finished
# nympha-ell_tx-ty_20180514_025-045.csv finished
# nympha-ell_tx-ty_20180514_025-050.csv finished
# nympha-ell_tx-ty_20180514_025-055.csv finished
# nympha-ell_tx-ty_20180514_025-060.csv finished
# nympha-ell_tx-ty_20180514_025-065.csv finished
# nympha-ell_tx-ty_20180514_025-070.csv finished
# nympha-ell_tx-ty_20180514_025-075.csv finished
# nympha-ell_tx-ty_20180514_025-080.csv finished
# nympha-ell_tx-ty_20180514_025-085.csv finished
# nympha-ell_tx-ty_20180514_025-090.csv finished
# nympha-ell_tx-ty_20180514_025-095.csv finished
# nympha-ell_tx-ty_20180514_025-100.csv finished
# nympha-ell_tx-ty_20180514_030-000.csv finished
# nympha-ell_tx-ty_20180514_030-005.csv finished
# nympha-ell_tx-ty_20180514_030-010.csv finished
# nympha-ell_tx-ty_20180514_030-015.csv finished
# nympha-ell_tx-ty_20180514_030-020.csv finished
# nympha-ell_tx-ty_20180514_030-025.csv finished
# nympha-ell_tx-ty_20180514_030-030.csv finished
# nympha-ell_tx-ty_20180514_030-035.csv finished
# nympha-ell_tx-ty_20180514_030-040.csv finished
# nympha-ell_tx-ty_20180514_030-045.csv finished
# nympha-ell_tx-ty_20180514_030-050.csv finished
# nympha-ell_tx-ty_20180514_030-055.csv finished
# nympha-ell_tx-ty_20180514_030-060.csv finished
# nympha-ell_tx-ty_20180514_030-065.csv finished
# nympha-ell_tx-ty_20180514_030-070.csv finished
# nympha-ell_tx-ty_20180514_030-075.csv finished
# nympha-ell_tx-ty_20180514_030-080.csv finished
# nympha-ell_tx-ty_20180514_030-085.csv finished
# nympha-ell_tx-ty_20180514_030-090.csv finished
# nympha-ell_tx-ty_20180514_030-095.csv finished
# nympha-ell_tx-ty_20180514_030-100.csv finished
# nympha-ell_tx-ty_20180514_035-000.csv finished
# nympha-ell_tx-ty_20180514_035-005.csv finished
# nympha-ell_tx-ty_20180514_035-010.csv finished
# nympha-ell_tx-ty_20180514_035-015.csv finished
# nympha-ell_tx-ty_20180514_035-020.csv finished
# nympha-ell_tx-ty_20180514_035-025.csv finished
# nympha-ell_tx-ty_20180514_035-030.csv finished
# nympha-ell_tx-ty_20180514_035-035.csv finished
# nympha-ell_tx-ty_20180514_035-040.csv finished
# nympha-ell_tx-ty_20180514_035-045.csv finished
# nympha-ell_tx-ty_20180514_035-050.csv finished
# nympha-ell_tx-ty_20180514_035-055.csv finished
# nympha-ell_tx-ty_20180514_035-060.csv finished
# nympha-ell_tx-ty_20180514_035-065.csv finished
# nympha-ell_tx-ty_20180514_035-070.csv finished
# nympha-ell_tx-ty_20180514_035-075.csv finished
# nympha-ell_tx-ty_20180514_035-080.csv finished
# nympha-ell_tx-ty_20180514_035-085.csv finished
# nympha-ell_tx-ty_20180514_035-090.csv finished
# nympha-ell_tx-ty_20180514_035-095.csv finished
# nympha-ell_tx-ty_20180514_035-100.csv finished
# nympha-ell_tx-ty_20180514_040-000.csv finished
# nympha-ell_tx-ty_20180514_040-005.csv finished
# nympha-ell_tx-ty_20180514_040-010.csv finished
# nympha-ell_tx-ty_20180514_040-015.csv finished
# nympha-ell_tx-ty_20180514_040-020.csv finished
# nympha-ell_tx-ty_20180514_040-025.csv finished
# nympha-ell_tx-ty_20180514_040-030.csv finished
# nympha-ell_tx-ty_20180514_040-035.csv finished
# nympha-ell_tx-ty_20180514_040-040.csv finished
# nympha-ell_tx-ty_20180514_040-045.csv finished
# nympha-ell_tx-ty_20180514_040-050.csv finished
# nympha-ell_tx-ty_20180514_040-055.csv finished
# nympha-ell_tx-ty_20180514_040-060.csv finished
# nympha-ell_tx-ty_20180514_040-065.csv finished
# nympha-ell_tx-ty_20180514_040-070.csv finished
# nympha-ell_tx-ty_20180514_040-075.csv finished
# nympha-ell_tx-ty_20180514_040-080.csv finished
# nympha-ell_tx-ty_20180514_040-085.csv finished
# nympha-ell_tx-ty_20180514_040-090.csv finished
# nympha-ell_tx-ty_20180514_040-095.csv finished
# nympha-ell_tx-ty_20180514_040-100.csv finished
# nympha-ell_tx-ty_20180514_045-000.csv finished
# nympha-ell_tx-ty_20180514_045-005.csv finished
# nympha-ell_tx-ty_20180514_045-010.csv finished
# nympha-ell_tx-ty_20180514_045-015.csv finished
# nympha-ell_tx-ty_20180514_045-020.csv finished
# nympha-ell_tx-ty_20180514_045-025.csv finished
# nympha-ell_tx-ty_20180514_045-030.csv finished
# nympha-ell_tx-ty_20180514_045-035.csv finished
# nympha-ell_tx-ty_20180514_045-040.csv finished
# nympha-ell_tx-ty_20180514_045-045.csv finished
# nympha-ell_tx-ty_20180514_045-050.csv finished
# nympha-ell_tx-ty_20180514_045-055.csv finished
# nympha-ell_tx-ty_20180514_045-060.csv finished
# nympha-ell_tx-ty_20180514_045-065.csv finished
# nympha-ell_tx-ty_20180514_045-070.csv finished
# nympha-ell_tx-ty_20180514_045-075.csv finished
# nympha-ell_tx-ty_20180514_045-080.csv finished
# nympha-ell_tx-ty_20180514_045-085.csv finished
# nympha-ell_tx-ty_20180514_045-090.csv finished
# nympha-ell_tx-ty_20180514_045-095.csv finished
# nympha-ell_tx-ty_20180514_045-100.csv finished
# nympha-ell_tx-ty_20180514_050-000.csv finished
# nympha-ell_tx-ty_20180514_050-005.csv finished
# nympha-ell_tx-ty_20180514_050-010.csv finished
# nympha-ell_tx-ty_20180514_050-015.csv finished
# nympha-ell_tx-ty_20180514_050-020.csv finished
# nympha-ell_tx-ty_20180514_050-025.csv finished
# nympha-ell_tx-ty_20180514_050-030.csv finished
# nympha-ell_tx-ty_20180514_050-035.csv finished
# nympha-ell_tx-ty_20180514_050-040.csv finished
# nympha-ell_tx-ty_20180514_050-045.csv finished
# nympha-ell_tx-ty_20180514_050-050.csv finished
# nympha-ell_tx-ty_20180514_050-055.csv finished
# nympha-ell_tx-ty_20180514_050-060.csv finished
# nympha-ell_tx-ty_20180514_050-065.csv finished
# nympha-ell_tx-ty_20180514_050-070.csv finished
# nympha-ell_tx-ty_20180514_050-075.csv finished
# nympha-ell_tx-ty_20180514_050-080.csv finished
# nympha-ell_tx-ty_20180514_050-085.csv finished
# nympha-ell_tx-ty_20180514_050-090.csv finished
# nympha-ell_tx-ty_20180514_050-095.csv finished
# nympha-ell_tx-ty_20180514_050-100.csv finished
# nympha-ell_tx-ty_20180514_055-000.csv finished
# nympha-ell_tx-ty_20180514_055-005.csv finished
# nympha-ell_tx-ty_20180514_055-010.csv finished
# nympha-ell_tx-ty_20180514_055-015.csv finished
# nympha-ell_tx-ty_20180514_055-020.csv finished
# nympha-ell_tx-ty_20180514_055-025.csv finished
# nympha-ell_tx-ty_20180514_055-030.csv finished
# nympha-ell_tx-ty_20180514_055-035.csv finished
# nympha-ell_tx-ty_20180514_055-040.csv finished
# nympha-ell_tx-ty_20180514_055-045.csv finished
# nympha-ell_tx-ty_20180514_055-050.csv finished
# nympha-ell_tx-ty_20180514_055-055.csv finished
# nympha-ell_tx-ty_20180514_055-060.csv finished
# nympha-ell_tx-ty_20180514_055-065.csv finished
# nympha-ell_tx-ty_20180514_055-070.csv finished
# nympha-ell_tx-ty_20180514_055-075.csv finished
# nympha-ell_tx-ty_20180514_055-080.csv finished
# nympha-ell_tx-ty_20180514_055-085.csv finished
# nympha-ell_tx-ty_20180514_055-090.csv finished
# nympha-ell_tx-ty_20180514_055-095.csv finished
# nympha-ell_tx-ty_20180514_055-100.csv finished
# nympha-ell_tx-ty_20180514_060-000.csv finished
# nympha-ell_tx-ty_20180514_060-005.csv finished
# nympha-ell_tx-ty_20180514_060-010.csv finished
# nympha-ell_tx-ty_20180514_060-015.csv finished
# nympha-ell_tx-ty_20180514_060-020.csv finished
# nympha-ell_tx-ty_20180514_060-025.csv finished
# nympha-ell_tx-ty_20180514_060-030.csv finished
# nympha-ell_tx-ty_20180514_060-035.csv finished
# nympha-ell_tx-ty_20180514_060-040.csv finished
# nympha-ell_tx-ty_20180514_060-045.csv finished
# nympha-ell_tx-ty_20180514_060-050.csv finished
# nympha-ell_tx-ty_20180514_060-055.csv finished
# nympha-ell_tx-ty_20180514_060-060.csv finished
# nympha-ell_tx-ty_20180514_060-065.csv finished
# nympha-ell_tx-ty_20180514_060-070.csv finished
# nympha-ell_tx-ty_20180514_060-075.csv finished
# nympha-ell_tx-ty_20180514_060-080.csv finished
# nympha-ell_tx-ty_20180514_060-085.csv finished
# nympha-ell_tx-ty_20180514_060-090.csv finished
# nympha-ell_tx-ty_20180514_060-095.csv finished
# nympha-ell_tx-ty_20180514_060-100.csv finished
# nympha-ell_tx-ty_20180514_065-000.csv finished
# nympha-ell_tx-ty_20180514_065-005.csv finished
# nympha-ell_tx-ty_20180514_065-010.csv finished
# nympha-ell_tx-ty_20180514_065-015.csv finished
# nympha-ell_tx-ty_20180514_065-020.csv finished
# nympha-ell_tx-ty_20180514_065-025.csv finished
# nympha-ell_tx-ty_20180514_065-030.csv finished
# nympha-ell_tx-ty_20180514_065-035.csv finished
# nympha-ell_tx-ty_20180514_065-040.csv finished
# nympha-ell_tx-ty_20180514_065-045.csv finished
# nympha-ell_tx-ty_20180514_065-050.csv finished
# nympha-ell_tx-ty_20180514_065-055.csv finished
# nympha-ell_tx-ty_20180514_065-060.csv finished
# nympha-ell_tx-ty_20180514_065-065.csv finished
# nympha-ell_tx-ty_20180514_065-070.csv finished
# nympha-ell_tx-ty_20180514_065-075.csv finished
# nympha-ell_tx-ty_20180514_065-080.csv finished
# nympha-ell_tx-ty_20180514_065-085.csv finished
# nympha-ell_tx-ty_20180514_065-090.csv finished
# nympha-ell_tx-ty_20180514_065-095.csv finished
# nympha-ell_tx-ty_20180514_065-100.csv finished
# nympha-ell_tx-ty_20180514_070-000.csv finished
# nympha-ell_tx-ty_20180514_070-005.csv finished
# nympha-ell_tx-ty_20180514_070-010.csv finished
# nympha-ell_tx-ty_20180514_070-015.csv finished
# nympha-ell_tx-ty_20180514_070-020.csv finished
# nympha-ell_tx-ty_20180514_070-025.csv finished
# nympha-ell_tx-ty_20180514_070-030.csv finished
# nympha-ell_tx-ty_20180514_070-035.csv finished
# nympha-ell_tx-ty_20180514_070-040.csv finished
# nympha-ell_tx-ty_20180514_070-045.csv finished
# nympha-ell_tx-ty_20180514_070-050.csv finished
# nympha-ell_tx-ty_20180514_070-055.csv finished
# nympha-ell_tx-ty_20180514_070-060.csv finished
# nympha-ell_tx-ty_20180514_070-065.csv finished
# nympha-ell_tx-ty_20180514_070-070.csv finished
# nympha-ell_tx-ty_20180514_070-075.csv finished
# nympha-ell_tx-ty_20180514_070-080.csv finished
# nympha-ell_tx-ty_20180514_070-085.csv finished
# nympha-ell_tx-ty_20180514_070-090.csv finished
# nympha-ell_tx-ty_20180514_070-095.csv finished
# nympha-ell_tx-ty_20180514_070-100.csv finished
# nympha-ell_tx-ty_20180514_075-000.csv finished
# nympha-ell_tx-ty_20180514_075-005.csv finished
# nympha-ell_tx-ty_20180514_075-010.csv finished
# nympha-ell_tx-ty_20180514_075-015.csv finished
# nympha-ell_tx-ty_20180514_075-020.csv finished
# nympha-ell_tx-ty_20180514_075-025.csv finished
# nympha-ell_tx-ty_20180514_075-030.csv finished
# nympha-ell_tx-ty_20180514_075-035.csv finished
# nympha-ell_tx-ty_20180514_075-040.csv finished
# nympha-ell_tx-ty_20180514_075-045.csv finished
# nympha-ell_tx-ty_20180514_075-050.csv finished
# nympha-ell_tx-ty_20180514_075-055.csv finished
# nympha-ell_tx-ty_20180514_075-060.csv finished
# nympha-ell_tx-ty_20180514_075-065.csv finished
# nympha-ell_tx-ty_20180514_075-070.csv finished
# nympha-ell_tx-ty_20180514_075-075.csv finished
# nympha-ell_tx-ty_20180514_075-080.csv finished
# nympha-ell_tx-ty_20180514_075-085.csv finished
# nympha-ell_tx-ty_20180514_075-090.csv finished
# nympha-ell_tx-ty_20180514_075-095.csv finished
# nympha-ell_tx-ty_20180514_075-100.csv finished
# nympha-ell_tx-ty_20180514_080-000.csv finished
# nympha-ell_tx-ty_20180514_080-005.csv finished
# nympha-ell_tx-ty_20180514_080-010.csv finished
# nympha-ell_tx-ty_20180514_080-015.csv finished
# nympha-ell_tx-ty_20180514_080-020.csv finished
# nympha-ell_tx-ty_20180514_080-025.csv finished
# nympha-ell_tx-ty_20180514_080-030.csv finished
# nympha-ell_tx-ty_20180514_080-035.csv finished
# nympha-ell_tx-ty_20180514_080-040.csv finished
# nympha-ell_tx-ty_20180514_080-045.csv finished
# nympha-ell_tx-ty_20180514_080-050.csv finished
# nympha-ell_tx-ty_20180514_080-055.csv finished
# nympha-ell_tx-ty_20180514_080-060.csv finished
# nympha-ell_tx-ty_20180514_080-065.csv finished
# nympha-ell_tx-ty_20180514_080-070.csv finished
# nympha-ell_tx-ty_20180514_080-075.csv finished
# nympha-ell_tx-ty_20180514_080-080.csv finished
# nympha-ell_tx-ty_20180514_080-085.csv finished
# nympha-ell_tx-ty_20180514_080-090.csv finished
# nympha-ell_tx-ty_20180514_080-095.csv finished
# nympha-ell_tx-ty_20180514_080-100.csv finished
# nympha-ell_tx-ty_20180514_085-000.csv finished
# nympha-ell_tx-ty_20180514_085-005.csv finished
# nympha-ell_tx-ty_20180514_085-010.csv finished
# nympha-ell_tx-ty_20180514_085-015.csv finished
# nympha-ell_tx-ty_20180514_085-020.csv finished
# nympha-ell_tx-ty_20180514_085-025.csv finished
# nympha-ell_tx-ty_20180514_085-030.csv finished
# nympha-ell_tx-ty_20180514_085-035.csv finished
# nympha-ell_tx-ty_20180514_085-040.csv finished
# nympha-ell_tx-ty_20180514_085-045.csv finished
# nympha-ell_tx-ty_20180514_085-050.csv finished
# nympha-ell_tx-ty_20180514_085-055.csv finished
# nympha-ell_tx-ty_20180514_085-060.csv finished
# nympha-ell_tx-ty_20180514_085-065.csv finished
# nympha-ell_tx-ty_20180514_085-070.csv finished
# nympha-ell_tx-ty_20180514_085-075.csv finished
# nympha-ell_tx-ty_20180514_085-080.csv finished
# nympha-ell_tx-ty_20180514_085-085.csv finished
# nympha-ell_tx-ty_20180514_085-090.csv finished
# nympha-ell_tx-ty_20180514_085-095.csv finished
# nympha-ell_tx-ty_20180514_085-100.csv finished
# nympha-ell_tx-ty_20180514_090-000.csv finished
# nympha-ell_tx-ty_20180514_090-005.csv finished
# nympha-ell_tx-ty_20180514_090-010.csv finished
# nympha-ell_tx-ty_20180514_090-015.csv finished
# nympha-ell_tx-ty_20180514_090-020.csv finished
# nympha-ell_tx-ty_20180514_090-025.csv finished
# nympha-ell_tx-ty_20180514_090-030.csv finished
# nympha-ell_tx-ty_20180514_090-035.csv finished
# nympha-ell_tx-ty_20180514_090-040.csv finished
# nympha-ell_tx-ty_20180514_090-045.csv finished
# nympha-ell_tx-ty_20180514_090-050.csv finished
# nympha-ell_tx-ty_20180514_090-055.csv finished
# nympha-ell_tx-ty_20180514_090-060.csv finished
# nympha-ell_tx-ty_20180514_090-065.csv finished
# nympha-ell_tx-ty_20180514_090-070.csv finished
# nympha-ell_tx-ty_20180514_090-075.csv finished
# nympha-ell_tx-ty_20180514_090-080.csv finished
# nympha-ell_tx-ty_20180514_090-085.csv finished
# nympha-ell_tx-ty_20180514_090-090.csv finished
# nympha-ell_tx-ty_20180514_090-095.csv finished
# nympha-ell_tx-ty_20180514_090-100.csv finished
# nympha-ell_tx-ty_20180514_095-000.csv finished
# nympha-ell_tx-ty_20180514_095-005.csv finished
# nympha-ell_tx-ty_20180514_095-010.csv finished
# nympha-ell_tx-ty_20180514_095-015.csv finished
# nympha-ell_tx-ty_20180514_095-020.csv finished
# nympha-ell_tx-ty_20180514_095-025.csv finished
# nympha-ell_tx-ty_20180514_095-030.csv finished
# nympha-ell_tx-ty_20180514_095-035.csv finished
# nympha-ell_tx-ty_20180514_095-040.csv finished
# nympha-ell_tx-ty_20180514_095-045.csv finished
# nympha-ell_tx-ty_20180514_095-050.csv finished
# nympha-ell_tx-ty_20180514_095-055.csv finished
# nympha-ell_tx-ty_20180514_095-060.csv finished
# nympha-ell_tx-ty_20180514_095-065.csv finished
# nympha-ell_tx-ty_20180514_095-070.csv finished
# nympha-ell_tx-ty_20180514_095-075.csv finished
# nympha-ell_tx-ty_20180514_095-080.csv finished
# nympha-ell_tx-ty_20180514_095-085.csv finished
# nympha-ell_tx-ty_20180514_095-090.csv finished
# nympha-ell_tx-ty_20180514_095-095.csv finished
# nympha-ell_tx-ty_20180514_095-100.csv finished
# nympha-ell_tx-ty_20180514_100-000.csv finished
# nympha-ell_tx-ty_20180514_100-005.csv finished
# nympha-ell_tx-ty_20180514_100-010.csv finished
# nympha-ell_tx-ty_20180514_100-015.csv finished
# nympha-ell_tx-ty_20180514_100-020.csv finished
# nympha-ell_tx-ty_20180514_100-025.csv finished
# nympha-ell_tx-ty_20180514_100-030.csv finished
# nympha-ell_tx-ty_20180514_100-035.csv finished
# nympha-ell_tx-ty_20180514_100-040.csv finished
# nympha-ell_tx-ty_20180514_100-045.csv finished
# nympha-ell_tx-ty_20180514_100-050.csv finished
# nympha-ell_tx-ty_20180514_100-055.csv finished
# nympha-ell_tx-ty_20180514_100-060.csv finished
# nympha-ell_tx-ty_20180514_100-065.csv finished
# nympha-ell_tx-ty_20180514_100-070.csv finished
# nympha-ell_tx-ty_20180514_100-075.csv finished
# nympha-ell_tx-ty_20180514_100-080.csv finished
# nympha-ell_tx-ty_20180514_100-085.csv finished
# nympha-ell_tx-ty_20180514_100-090.csv finished
# nympha-ell_tx-ty_20180514_100-095.csv finished
# nympha-ell_tx-ty_20180514_100-100.csv finished
# completed
