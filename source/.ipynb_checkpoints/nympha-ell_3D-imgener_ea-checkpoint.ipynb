# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import os
import glob
import matplotlib.cm as cm

lim = 55
reso = 90
db = 10

#directory of output files of "nympha-ell_csv_ea.py"'
csv_dir = 'here'
csv_files = csv_dir + '/*.csv'

#directory of output folder of this note
png_dir = 'there'

for name in glob.glob(csv_files):
    df = pd.read_csv(name, header = None)
    data = np.array(df)
    head, tail = os.path.split(name)
    filename, ext = os.path.splitext(tail)
    imagename = filename + '_3d' + ".png"
    
    os.chdir(png_dir)
    #making fig
    fig = plt.figure(figsize = (6.4, 4.8))
    ax = fig.gca(projection='3d')
    
    #NaN check
    if data[0,0] != data[0,0]:
        continue
    
    for i in range(0, 102, 1):
        start = i*reso*reso
        end = (i+1)*reso*reso
        subdata = data[start:end, :].reshape((90,90,3))
        ax.plot_surface(subdata[:,:,0], subdata[:,:,1], subdata[:,:,2], antialiased=True, color = "crimson")
    
        #adjusting image aspect
    ax.set_aspect((lim + db) / (2*lim))
    ax.set_xlim3d(-lim, lim)
    ax.set_ylim3d(-lim, lim)
    ax.set_zlim3d(-db, lim)
        
    plt.axis('off')
    plt.box('off')
        
    plt.savefig(imagename)
    print(imagename)
    os.chdir(csv_dir)

print("completed")
# Out:
# C:\Users\Shiryu\Anaconda3\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# nympha-ell_ea_20180530_00-00_3d.png
# nympha-ell_ea_20180530_00-01_3d.png
# nympha-ell_ea_20180530_00-02_3d.png
# nympha-ell_ea_20180530_00-03_3d.png
# nympha-ell_ea_20180530_00-04_3d.png
# nympha-ell_ea_20180530_00-05_3d.png
# nympha-ell_ea_20180530_00-06_3d.png
# nympha-ell_ea_20180530_00-07_3d.png
# nympha-ell_ea_20180530_00-08_3d.png
# nympha-ell_ea_20180530_00-09_3d.png
# nympha-ell_ea_20180530_01-01_3d.png
# nympha-ell_ea_20180530_01-02_3d.png
# nympha-ell_ea_20180530_01-03_3d.png
# nympha-ell_ea_20180530_01-04_3d.png
# nympha-ell_ea_20180530_01-05_3d.png
# nympha-ell_ea_20180530_01-06_3d.png
# nympha-ell_ea_20180530_01-07_3d.png
# nympha-ell_ea_20180530_01-08_3d.png
# nympha-ell_ea_20180530_01-09_3d.png
# nympha-ell_ea_20180530_02-02_3d.png
# nympha-ell_ea_20180530_02-03_3d.png
# nympha-ell_ea_20180530_02-04_3d.png
# nympha-ell_ea_20180530_02-05_3d.png
# nympha-ell_ea_20180530_02-06_3d.png
# nympha-ell_ea_20180530_02-07_3d.png
# nympha-ell_ea_20180530_02-08_3d.png
# nympha-ell_ea_20180530_02-09_3d.png
# nympha-ell_ea_20180530_03-03_3d.png
# nympha-ell_ea_20180530_03-04_3d.png
# nympha-ell_ea_20180530_03-05_3d.png
# nympha-ell_ea_20180530_03-06_3d.png
# nympha-ell_ea_20180530_03-07_3d.png
# nympha-ell_ea_20180530_03-08_3d.png
# nympha-ell_ea_20180530_03-09_3d.png
# nympha-ell_ea_20180530_04-04_3d.png
# nympha-ell_ea_20180530_04-05_3d.png
# nympha-ell_ea_20180530_04-06_3d.png
# nympha-ell_ea_20180530_04-07_3d.png
# nympha-ell_ea_20180530_04-08_3d.png
# nympha-ell_ea_20180530_04-09_3d.png
# nympha-ell_ea_20180530_05-05_3d.png
# nympha-ell_ea_20180530_05-06_3d.png
# nympha-ell_ea_20180530_05-07_3d.png
# nympha-ell_ea_20180530_05-08_3d.png
# nympha-ell_ea_20180530_05-09_3d.png
# nympha-ell_ea_20180530_06-06_3d.png
# nympha-ell_ea_20180530_06-07_3d.png
# nympha-ell_ea_20180530_06-08_3d.png
# nympha-ell_ea_20180530_06-09_3d.png
# nympha-ell_ea_20180530_07-07_3d.png
# nympha-ell_ea_20180530_07-08_3d.png
# nympha-ell_ea_20180530_07-09_3d.png
# nympha-ell_ea_20180530_08-08_3d.png
# nympha-ell_ea_20180530_08-09_3d.png
# nympha-ell_ea_20180530_09-09_3d.png
# completed
