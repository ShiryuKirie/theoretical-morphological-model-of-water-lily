# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import os
import glob
import matplotlib.cm as cm

lim = 55
reso = 90
db = 10

#directory of output files of "nympha-ell_csv_pitch.py"'
csv_dir = 'here'
csv_files = csv_dir + '/*.csv'

#directory of output folder of this note
png_dir = 'there'

for name in glob.glob(csv_files):
    df = pd.read_csv(name, header = None)
    data = np.array(df)
    head, tail = os.path.split(name)
    filename, ext = os.path.splitext(tail)
    imagename = filename + '_3d' + ".png"
    
    os.chdir(png_dir)
    #making fig
    fig = plt.figure(figsize = (6.4, 4.8))
    ax = fig.gca(projection='3d')
    
    #NaN check
    if data[0,0] != data[0,0]:
        continue
    
    for i in range(0, 102, 1):
        start = i*reso*reso
        end = (i+1)*reso*reso
        subdata = data[start:end, :].reshape((90,90,3))
        ax.plot_surface(subdata[:,:,0], subdata[:,:,1], subdata[:,:,2], antialiased=True, color = "crimson")
    
        #adjusting image aspect
    ax.set_aspect((lim + db) / (2*lim))
    ax.set_xlim3d(-lim, lim)
    ax.set_ylim3d(-lim, lim)
    ax.set_zlim3d(-db, lim)
        
    plt.axis('off')
    plt.box('off')
        
    plt.savefig(imagename)
    print(imagename)
    os.chdir(csv_dir)

print("completed")
# Out:
# nympha-ell_pitch_20180514_0000_3d.png
# nympha-ell_pitch_20180514_0010_3d.png
# nympha-ell_pitch_20180514_0020_3d.png
# nympha-ell_pitch_20180514_0030_3d.png
# nympha-ell_pitch_20180514_0040_3d.png
# nympha-ell_pitch_20180514_0050_3d.png
# nympha-ell_pitch_20180514_0060_3d.png
# nympha-ell_pitch_20180514_0070_3d.png
# nympha-ell_pitch_20180514_0080_3d.png
# nympha-ell_pitch_20180514_0090_3d.png
# nympha-ell_pitch_20180514_0100_3d.png
# nympha-ell_pitch_20180514_0110_3d.png
# nympha-ell_pitch_20180514_0120_3d.png
# nympha-ell_pitch_20180514_0130_3d.png
# nympha-ell_pitch_20180514_0140_3d.png
# nympha-ell_pitch_20180514_0150_3d.png
# nympha-ell_pitch_20180514_0160_3d.png
# nympha-ell_pitch_20180514_0170_3d.png
# nympha-ell_pitch_20180514_0180_3d.png
# nympha-ell_pitch_20180514_0190_3d.png
# C:\Users\Shiryu\Anaconda3\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# nympha-ell_pitch_20180514_0200_3d.png
# nympha-ell_pitch_20180514_0210_3d.png
# nympha-ell_pitch_20180514_0220_3d.png
# nympha-ell_pitch_20180514_0230_3d.png
# nympha-ell_pitch_20180514_0240_3d.png
# nympha-ell_pitch_20180514_0250_3d.png
# nympha-ell_pitch_20180514_0260_3d.png
# nympha-ell_pitch_20180514_0270_3d.png
# nympha-ell_pitch_20180514_0280_3d.png
# nympha-ell_pitch_20180514_0290_3d.png
# nympha-ell_pitch_20180514_0300_3d.png
# nympha-ell_pitch_20180514_0310_3d.png
# nympha-ell_pitch_20180514_0320_3d.png
# nympha-ell_pitch_20180514_0330_3d.png
# nympha-ell_pitch_20180514_0340_3d.png
# nympha-ell_pitch_20180514_0350_3d.png
# nympha-ell_pitch_20180514_0360_3d.png
# nympha-ell_pitch_20180514_0370_3d.png
