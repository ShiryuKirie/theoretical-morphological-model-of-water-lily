# %%
'''
===========================
nympha_ellipse
===========================

Demonstrates a flower of nymphaea as 3D surface(ellipsoid) objects.

'''

from mpl_toolkits.mplot3d import Axes3D
from matplotlib.patches import Circle
import mpl_toolkits.mplot3d.art3d as art3d
import matplotlib.pyplot as plt
import numpy as np
import csv
import os

# setting organ
class Organ :
	def __init__(self, rx, ry, rz, xdeg, zdeg, zpo, hb, col, reso):

		self.rx = rx #minor length
		self.ry = ry #major length
		self.rz = rz 

		self.reso = reso #surfaces resolution

#organ's shape as ellipsoid surface
		u = np.linspace(0, 2 * np.pi, reso)
		v = np.linspace(0, 1/2*np.pi, reso)
		x = self.rx * np.outer(np.cos(u), np.sin(v))
		y = self.ry * np.outer(np.sin(u), np.sin(v))
		z = -self.rz * np.outer(np.ones(np.size(u)), np.cos(v))
		xyz = np.dstack((x, y, z))

#rotate & transfer organ
		self.xdeg = xdeg
		xrot = np.array([[1, 0, 0],
						[0, np.cos(xdeg), -1*np.sin(xdeg)],
						[0, np.sin(xdeg), np.cos(xdeg)]])
		self.zdeg = zdeg
		zrot = np.array([[np.cos(zdeg), -1*np.sin(zdeg), 0],
						[np.sin(zdeg), np.cos(zdeg), 0],
						[0, 0, 1]])

		for i in range(reso):
			for j in range(reso):
				xyz[i,j,:] = np.dot(xrot, xyz[i,j,:].T)
				xyz[i,j,:] = xyz[i,j,:] + [0, self.ry * np.cos(xdeg) + db, self.ry * np.sin(xdeg) + zpo]
				xyz[i,j,:] = np.dot(zrot, xyz[i,j,:].T)
				if record == True:
					csvWriter.writerow(xyz[i,j,:]) #record in csv

		self.col = col

##########################################################################################

#setting parameter of each organ

def orgforms(dx1 = 0.040, dx2 = 0.001, x0 = 10, xt = 2.0, txi = 20, dy1 = 0.020, dy2 = 0.004, y0= 35, yt = 12.0, tyi = 20):
#parameter to set size of ellipsoid

	rxs = np.linspace(0, n_organ-1, n_organ) # minor length
	rxs[0:txi] = x0 - x0 * dx1 * rxs[0:txi] # x = x0 - ai and  a = x0*dx1
	rxs[txi:n_organ] = xt - x0 * dx2 * (rxs[txi:n_organ] - txi) # x = xt - b(i-tx) and b = x0*dx2 and tx = txi-1
	rxs[rxs < 0.5] = 0.5 #limit of minimum length
    
	rys = np.linspace(0, n_organ-1, n_organ) # major length
	rys[0:tyi] = y0 - y0 * dy1 * rys[0:tyi] # y = y0 - ai and  a = y0*dy1
	rys[tyi:n_organ] = yt - y0 * dy2 * (rys[tyi:n_organ] - tyi) # y = yt - b(i-ty) and b = y0*dy2 and ty = tyi-1
	rys[rys < 0.5] = 0.5 #limit of minimum length
    
	#the point finishing transition
	tmax = max([txi, tyi]) 

	#organs swell
	rzs = np.zeros(n_organ)
	for i in range(n_organ):
		if i < tmax:
			rzs[i] = 0 #mode1
		else:
			rzs[i] = 0 #mode2

	return (rxs, rys, tmax, rzs)

####################################################################
#parameter to elevate each organ

def orgposi(pitch = -0.01):

#parameter to rotate each organ along z-axis
	zdegs = np.zeros(n_organ)
	zdegs[0] = 0
	zdegs[1] = np.pi
	zdegs[2] = np.pi * 3/2
	zdegs[3] = np.pi * 1/2
	for i in range(4, n_organ):
		zdegs[i] = zdegs[i - 1] + 137.5/180 *  np.pi

# height where each organ is put 
	zpos = np.zeros(n_organ)
	dzps = np.exp(pitch * zdegs)
	zpos[0] = 0
	zpos[1] = 0
	zpos[2] = 0
	zpos[3] = 0
	for i in range (1, n_organ):
		zpos[i] = zpos[i-1] + dzps[i]
	zpos = zpos/max(zpos) * hb

	return (zdegs, zpos)

########################################################################

def elevangle(max_ang = np.pi / 4, min_ang = np.pi / 4):

	xdegs = np.zeros(n_organ)
	xdegs[0:4] = min_ang
	for i in range(4, n_organ):
		if i < tmax:
			xdegs[i] = xdegs[i - 1] + (max_ang - min_ang) / (tmax-4)
		else:
			xdegs[i] = 90/180 * np.pi

	return xdegs
##########################################################################################
#setting

n_organ = 100
reso = 90

db = 10 #half of Base' s Diameter
hb = 5 #Height of Base
bu = np.linspace(0, 2 * np.pi, reso)

#upper part of base
bux = np.outer(db * np.cos(bu), np.ones(np.size(bu)))
buy = np.outer(db * np.sin(bu), np.ones(np.size(bu)))
buz = np.outer(np.ones(np.size(bu)), np.linspace(0, hb, reso))

#uppermost part of base
upp = Circle((0, 0), db, color = "red")

#basal part of base
bv = np.linspace(0, 1/2*np.pi, reso)
bbx = -db * np.outer(np.cos(bu), np.sin(bv))
bby = -db * np.outer(np.sin(bu), np.sin(bv))
bbz = -db * np.outer(np.ones(np.size(bu)), np.cos(bv))

##########################################################################################

#csv file
#True -> output into the file
dir = "here" # fill the output directory
os.chdir(dir)
record = True
namehead = "nympha-ell_x0-y0"

for curr_x0 in range(5, 121, 5):
    for curr_y0 in range(5, 121, 5):
        namebody = '_' + str(int(curr_x0)).zfill(3) + '-' + str(int(curr_y0)).zfill(3)
        
        if record == True:
            csv_coo = open(namehead + namebody + '.csv', 'x', newline='')
            csvWriter = csv.writer(csv_coo)
            for i in range(reso):
                for j in range(reso):
                    csvWriter.writerow([bux[i,j], buy[i,j], buz[i,j]])
                    csvWriter.writerow([bbx[i,j], bby[i,j], bbz[i,j]])
                
        #draw each organ
        rxs, rys, tmax, rzs = orgforms(x0 = curr_x0, y0 = curr_y0)
        zdegs, zpos = orgposi()
        xdegs = elevangle() 

        for n in range(n_organ):
            rx = rxs[n]
            ry = rys[n]
            rz = rzs[n]
            xdeg = xdegs[n]
            zdeg = zdegs[n]
            zpo = zpos[n]
            col = "red"
            organ = Organ(rx, ry, rz, xdeg, zdeg, zpo, hb, col, reso)
       
        if record == True:
            csv_coo.close()
            print(namehead + namebody + '.csv finished')

print("completed")
# Out:
# nympha-ell_x0-y0_20180517_005-005.csv finished
# nympha-ell_x0-y0_20180517_005-010.csv finished
# nympha-ell_x0-y0_20180517_005-015.csv finished
# nympha-ell_x0-y0_20180517_005-020.csv finished
# nympha-ell_x0-y0_20180517_005-025.csv finished
# nympha-ell_x0-y0_20180517_005-030.csv finished
# nympha-ell_x0-y0_20180517_005-035.csv finished
# nympha-ell_x0-y0_20180517_005-040.csv finished
# nympha-ell_x0-y0_20180517_005-045.csv finished
# nympha-ell_x0-y0_20180517_005-050.csv finished
# nympha-ell_x0-y0_20180517_005-055.csv finished
# nympha-ell_x0-y0_20180517_005-060.csv finished
# nympha-ell_x0-y0_20180517_005-065.csv finished
# nympha-ell_x0-y0_20180517_005-070.csv finished
# nympha-ell_x0-y0_20180517_005-075.csv finished
# nympha-ell_x0-y0_20180517_005-080.csv finished
# nympha-ell_x0-y0_20180517_005-085.csv finished
# nympha-ell_x0-y0_20180517_005-090.csv finished
# nympha-ell_x0-y0_20180517_005-095.csv finished
# nympha-ell_x0-y0_20180517_005-100.csv finished
# nympha-ell_x0-y0_20180517_005-105.csv finished
# nympha-ell_x0-y0_20180517_005-110.csv finished
# nympha-ell_x0-y0_20180517_005-115.csv finished
# nympha-ell_x0-y0_20180517_005-120.csv finished
# nympha-ell_x0-y0_20180517_010-005.csv finished
# nympha-ell_x0-y0_20180517_010-010.csv finished
# nympha-ell_x0-y0_20180517_010-015.csv finished
# nympha-ell_x0-y0_20180517_010-020.csv finished
# nympha-ell_x0-y0_20180517_010-025.csv finished
# nympha-ell_x0-y0_20180517_010-030.csv finished
# nympha-ell_x0-y0_20180517_010-035.csv finished
# nympha-ell_x0-y0_20180517_010-040.csv finished
# nympha-ell_x0-y0_20180517_010-045.csv finished
# nympha-ell_x0-y0_20180517_010-050.csv finished
# nympha-ell_x0-y0_20180517_010-055.csv finished
# nympha-ell_x0-y0_20180517_010-060.csv finished
# nympha-ell_x0-y0_20180517_010-065.csv finished
# nympha-ell_x0-y0_20180517_010-070.csv finished
# nympha-ell_x0-y0_20180517_010-075.csv finished
# nympha-ell_x0-y0_20180517_010-080.csv finished
# nympha-ell_x0-y0_20180517_010-085.csv finished
# nympha-ell_x0-y0_20180517_010-090.csv finished
# nympha-ell_x0-y0_20180517_010-095.csv finished
# nympha-ell_x0-y0_20180517_010-100.csv finished
# nympha-ell_x0-y0_20180517_010-105.csv finished
# nympha-ell_x0-y0_20180517_010-110.csv finished
# nympha-ell_x0-y0_20180517_010-115.csv finished
# nympha-ell_x0-y0_20180517_010-120.csv finished
# nympha-ell_x0-y0_20180517_015-005.csv finished
# nympha-ell_x0-y0_20180517_015-010.csv finished
# nympha-ell_x0-y0_20180517_015-015.csv finished
# nympha-ell_x0-y0_20180517_015-020.csv finished
# nympha-ell_x0-y0_20180517_015-025.csv finished
# nympha-ell_x0-y0_20180517_015-030.csv finished
# nympha-ell_x0-y0_20180517_015-035.csv finished
# nympha-ell_x0-y0_20180517_015-040.csv finished
# nympha-ell_x0-y0_20180517_015-045.csv finished
# nympha-ell_x0-y0_20180517_015-050.csv finished
# nympha-ell_x0-y0_20180517_015-055.csv finished
# nympha-ell_x0-y0_20180517_015-060.csv finished
# nympha-ell_x0-y0_20180517_015-065.csv finished
# nympha-ell_x0-y0_20180517_015-070.csv finished
# nympha-ell_x0-y0_20180517_015-075.csv finished
# nympha-ell_x0-y0_20180517_015-080.csv finished
# nympha-ell_x0-y0_20180517_015-085.csv finished
# nympha-ell_x0-y0_20180517_015-090.csv finished
# nympha-ell_x0-y0_20180517_015-095.csv finished
# nympha-ell_x0-y0_20180517_015-100.csv finished
# nympha-ell_x0-y0_20180517_015-105.csv finished
# nympha-ell_x0-y0_20180517_015-110.csv finished
# nympha-ell_x0-y0_20180517_015-115.csv finished
# nympha-ell_x0-y0_20180517_015-120.csv finished
# nympha-ell_x0-y0_20180517_020-005.csv finished
# nympha-ell_x0-y0_20180517_020-010.csv finished
# nympha-ell_x0-y0_20180517_020-015.csv finished
# nympha-ell_x0-y0_20180517_020-020.csv finished
# nympha-ell_x0-y0_20180517_020-025.csv finished
# nympha-ell_x0-y0_20180517_020-030.csv finished
# nympha-ell_x0-y0_20180517_020-035.csv finished
# nympha-ell_x0-y0_20180517_020-040.csv finished
# nympha-ell_x0-y0_20180517_020-045.csv finished
# nympha-ell_x0-y0_20180517_020-050.csv finished
# nympha-ell_x0-y0_20180517_020-055.csv finished
# nympha-ell_x0-y0_20180517_020-060.csv finished
# nympha-ell_x0-y0_20180517_020-065.csv finished
# nympha-ell_x0-y0_20180517_020-070.csv finished
# nympha-ell_x0-y0_20180517_020-075.csv finished
# nympha-ell_x0-y0_20180517_020-080.csv finished
# nympha-ell_x0-y0_20180517_020-085.csv finished
# nympha-ell_x0-y0_20180517_020-090.csv finished
# nympha-ell_x0-y0_20180517_020-095.csv finished
# nympha-ell_x0-y0_20180517_020-100.csv finished
# nympha-ell_x0-y0_20180517_020-105.csv finished
# nympha-ell_x0-y0_20180517_020-110.csv finished
# nympha-ell_x0-y0_20180517_020-115.csv finished
# nympha-ell_x0-y0_20180517_020-120.csv finished
# nympha-ell_x0-y0_20180517_025-005.csv finished
# nympha-ell_x0-y0_20180517_025-010.csv finished
# nympha-ell_x0-y0_20180517_025-015.csv finished
# nympha-ell_x0-y0_20180517_025-020.csv finished
# nympha-ell_x0-y0_20180517_025-025.csv finished
# nympha-ell_x0-y0_20180517_025-030.csv finished
# nympha-ell_x0-y0_20180517_025-035.csv finished
# nympha-ell_x0-y0_20180517_025-040.csv finished
# nympha-ell_x0-y0_20180517_025-045.csv finished
# nympha-ell_x0-y0_20180517_025-050.csv finished
# nympha-ell_x0-y0_20180517_025-055.csv finished
# nympha-ell_x0-y0_20180517_025-060.csv finished
# nympha-ell_x0-y0_20180517_025-065.csv finished
# nympha-ell_x0-y0_20180517_025-070.csv finished
# nympha-ell_x0-y0_20180517_025-075.csv finished
# nympha-ell_x0-y0_20180517_025-080.csv finished
# nympha-ell_x0-y0_20180517_025-085.csv finished
# nympha-ell_x0-y0_20180517_025-090.csv finished
# nympha-ell_x0-y0_20180517_025-095.csv finished
# nympha-ell_x0-y0_20180517_025-100.csv finished
# nympha-ell_x0-y0_20180517_025-105.csv finished
# nympha-ell_x0-y0_20180517_025-110.csv finished
# nympha-ell_x0-y0_20180517_025-115.csv finished
# nympha-ell_x0-y0_20180517_025-120.csv finished
# nympha-ell_x0-y0_20180517_030-005.csv finished
# nympha-ell_x0-y0_20180517_030-010.csv finished
# nympha-ell_x0-y0_20180517_030-015.csv finished
# nympha-ell_x0-y0_20180517_030-020.csv finished
# nympha-ell_x0-y0_20180517_030-025.csv finished
# nympha-ell_x0-y0_20180517_030-030.csv finished
# nympha-ell_x0-y0_20180517_030-035.csv finished
# nympha-ell_x0-y0_20180517_030-040.csv finished
# nympha-ell_x0-y0_20180517_030-045.csv finished
# nympha-ell_x0-y0_20180517_030-050.csv finished
# nympha-ell_x0-y0_20180517_030-055.csv finished
# nympha-ell_x0-y0_20180517_030-060.csv finished
# nympha-ell_x0-y0_20180517_030-065.csv finished
# nympha-ell_x0-y0_20180517_030-070.csv finished
# nympha-ell_x0-y0_20180517_030-075.csv finished
# nympha-ell_x0-y0_20180517_030-080.csv finished
# nympha-ell_x0-y0_20180517_030-085.csv finished
# nympha-ell_x0-y0_20180517_030-090.csv finished
# nympha-ell_x0-y0_20180517_030-095.csv finished
# nympha-ell_x0-y0_20180517_030-100.csv finished
# nympha-ell_x0-y0_20180517_030-105.csv finished
# nympha-ell_x0-y0_20180517_030-110.csv finished
# nympha-ell_x0-y0_20180517_030-115.csv finished
# nympha-ell_x0-y0_20180517_030-120.csv finished
# nympha-ell_x0-y0_20180517_035-005.csv finished
# nympha-ell_x0-y0_20180517_035-010.csv finished
# nympha-ell_x0-y0_20180517_035-015.csv finished
# nympha-ell_x0-y0_20180517_035-020.csv finished
# nympha-ell_x0-y0_20180517_035-025.csv finished
# nympha-ell_x0-y0_20180517_035-030.csv finished
# nympha-ell_x0-y0_20180517_035-035.csv finished
# nympha-ell_x0-y0_20180517_035-040.csv finished
# nympha-ell_x0-y0_20180517_035-045.csv finished
# nympha-ell_x0-y0_20180517_035-050.csv finished
# nympha-ell_x0-y0_20180517_035-055.csv finished
# nympha-ell_x0-y0_20180517_035-060.csv finished
# nympha-ell_x0-y0_20180517_035-065.csv finished
# nympha-ell_x0-y0_20180517_035-070.csv finished
# nympha-ell_x0-y0_20180517_035-075.csv finished
# nympha-ell_x0-y0_20180517_035-080.csv finished
# nympha-ell_x0-y0_20180517_035-085.csv finished
# nympha-ell_x0-y0_20180517_035-090.csv finished
# nympha-ell_x0-y0_20180517_035-095.csv finished
# nympha-ell_x0-y0_20180517_035-100.csv finished
# nympha-ell_x0-y0_20180517_035-105.csv finished
# nympha-ell_x0-y0_20180517_035-110.csv finished
# nympha-ell_x0-y0_20180517_035-115.csv finished
# nympha-ell_x0-y0_20180517_035-120.csv finished
# nympha-ell_x0-y0_20180517_040-005.csv finished
# nympha-ell_x0-y0_20180517_040-010.csv finished
# nympha-ell_x0-y0_20180517_040-015.csv finished
# nympha-ell_x0-y0_20180517_040-020.csv finished
# nympha-ell_x0-y0_20180517_040-025.csv finished
# nympha-ell_x0-y0_20180517_040-030.csv finished
# nympha-ell_x0-y0_20180517_040-035.csv finished
# nympha-ell_x0-y0_20180517_040-040.csv finished
# nympha-ell_x0-y0_20180517_040-045.csv finished
# nympha-ell_x0-y0_20180517_040-050.csv finished
# nympha-ell_x0-y0_20180517_040-055.csv finished
# nympha-ell_x0-y0_20180517_040-060.csv finished
# nympha-ell_x0-y0_20180517_040-065.csv finished
# nympha-ell_x0-y0_20180517_040-070.csv finished
# nympha-ell_x0-y0_20180517_040-075.csv finished
# nympha-ell_x0-y0_20180517_040-080.csv finished
# nympha-ell_x0-y0_20180517_040-085.csv finished
# nympha-ell_x0-y0_20180517_040-090.csv finished
# nympha-ell_x0-y0_20180517_040-095.csv finished
# nympha-ell_x0-y0_20180517_040-100.csv finished
# nympha-ell_x0-y0_20180517_040-105.csv finished
# nympha-ell_x0-y0_20180517_040-110.csv finished
# nympha-ell_x0-y0_20180517_040-115.csv finished
# nympha-ell_x0-y0_20180517_040-120.csv finished
# nympha-ell_x0-y0_20180517_045-005.csv finished
# nympha-ell_x0-y0_20180517_045-010.csv finished
# nympha-ell_x0-y0_20180517_045-015.csv finished
# nympha-ell_x0-y0_20180517_045-020.csv finished
# nympha-ell_x0-y0_20180517_045-025.csv finished
# nympha-ell_x0-y0_20180517_045-030.csv finished
# nympha-ell_x0-y0_20180517_045-035.csv finished
# nympha-ell_x0-y0_20180517_045-040.csv finished
# nympha-ell_x0-y0_20180517_045-045.csv finished
# nympha-ell_x0-y0_20180517_045-050.csv finished
# nympha-ell_x0-y0_20180517_045-055.csv finished
# nympha-ell_x0-y0_20180517_045-060.csv finished
# nympha-ell_x0-y0_20180517_045-065.csv finished
# nympha-ell_x0-y0_20180517_045-070.csv finished
# nympha-ell_x0-y0_20180517_045-075.csv finished
# nympha-ell_x0-y0_20180517_045-080.csv finished
# nympha-ell_x0-y0_20180517_045-085.csv finished
# nympha-ell_x0-y0_20180517_045-090.csv finished
# nympha-ell_x0-y0_20180517_045-095.csv finished
# nympha-ell_x0-y0_20180517_045-100.csv finished
# nympha-ell_x0-y0_20180517_045-105.csv finished
# nympha-ell_x0-y0_20180517_045-110.csv finished
# nympha-ell_x0-y0_20180517_045-115.csv finished
# nympha-ell_x0-y0_20180517_045-120.csv finished
# nympha-ell_x0-y0_20180517_050-005.csv finished
# nympha-ell_x0-y0_20180517_050-010.csv finished
# nympha-ell_x0-y0_20180517_050-015.csv finished
# nympha-ell_x0-y0_20180517_050-020.csv finished
# nympha-ell_x0-y0_20180517_050-025.csv finished
# nympha-ell_x0-y0_20180517_050-030.csv finished
# nympha-ell_x0-y0_20180517_050-035.csv finished
# nympha-ell_x0-y0_20180517_050-040.csv finished
# nympha-ell_x0-y0_20180517_050-045.csv finished
# nympha-ell_x0-y0_20180517_050-050.csv finished
# nympha-ell_x0-y0_20180517_050-055.csv finished
# nympha-ell_x0-y0_20180517_050-060.csv finished
# nympha-ell_x0-y0_20180517_050-065.csv finished
# nympha-ell_x0-y0_20180517_050-070.csv finished
# nympha-ell_x0-y0_20180517_050-075.csv finished
# nympha-ell_x0-y0_20180517_050-080.csv finished
# nympha-ell_x0-y0_20180517_050-085.csv finished
# nympha-ell_x0-y0_20180517_050-090.csv finished
# nympha-ell_x0-y0_20180517_050-095.csv finished
# nympha-ell_x0-y0_20180517_050-100.csv finished
# nympha-ell_x0-y0_20180517_050-105.csv finished
# nympha-ell_x0-y0_20180517_050-110.csv finished
# nympha-ell_x0-y0_20180517_050-115.csv finished
# nympha-ell_x0-y0_20180517_050-120.csv finished
# nympha-ell_x0-y0_20180517_055-005.csv finished
# nympha-ell_x0-y0_20180517_055-010.csv finished
# nympha-ell_x0-y0_20180517_055-015.csv finished
# nympha-ell_x0-y0_20180517_055-020.csv finished
# nympha-ell_x0-y0_20180517_055-025.csv finished
# nympha-ell_x0-y0_20180517_055-030.csv finished
# nympha-ell_x0-y0_20180517_055-035.csv finished
# nympha-ell_x0-y0_20180517_055-040.csv finished
# nympha-ell_x0-y0_20180517_055-045.csv finished
# nympha-ell_x0-y0_20180517_055-050.csv finished
# nympha-ell_x0-y0_20180517_055-055.csv finished
# nympha-ell_x0-y0_20180517_055-060.csv finished
# nympha-ell_x0-y0_20180517_055-065.csv finished
# nympha-ell_x0-y0_20180517_055-070.csv finished
# nympha-ell_x0-y0_20180517_055-075.csv finished
# nympha-ell_x0-y0_20180517_055-080.csv finished
# nympha-ell_x0-y0_20180517_055-085.csv finished
# nympha-ell_x0-y0_20180517_055-090.csv finished
# nympha-ell_x0-y0_20180517_055-095.csv finished
# nympha-ell_x0-y0_20180517_055-100.csv finished
# nympha-ell_x0-y0_20180517_055-105.csv finished
# nympha-ell_x0-y0_20180517_055-110.csv finished
# nympha-ell_x0-y0_20180517_055-115.csv finished
# nympha-ell_x0-y0_20180517_055-120.csv finished
# nympha-ell_x0-y0_20180517_060-005.csv finished
# nympha-ell_x0-y0_20180517_060-010.csv finished
# nympha-ell_x0-y0_20180517_060-015.csv finished
# nympha-ell_x0-y0_20180517_060-020.csv finished
# nympha-ell_x0-y0_20180517_060-025.csv finished
# nympha-ell_x0-y0_20180517_060-030.csv finished
# nympha-ell_x0-y0_20180517_060-035.csv finished
# nympha-ell_x0-y0_20180517_060-040.csv finished
# nympha-ell_x0-y0_20180517_060-045.csv finished
# nympha-ell_x0-y0_20180517_060-050.csv finished
# nympha-ell_x0-y0_20180517_060-055.csv finished
# nympha-ell_x0-y0_20180517_060-060.csv finished
# nympha-ell_x0-y0_20180517_060-065.csv finished
# nympha-ell_x0-y0_20180517_060-070.csv finished
# nympha-ell_x0-y0_20180517_060-075.csv finished
# nympha-ell_x0-y0_20180517_060-080.csv finished
# nympha-ell_x0-y0_20180517_060-085.csv finished
# nympha-ell_x0-y0_20180517_060-090.csv finished
# nympha-ell_x0-y0_20180517_060-095.csv finished
# nympha-ell_x0-y0_20180517_060-100.csv finished
# nympha-ell_x0-y0_20180517_060-105.csv finished
# nympha-ell_x0-y0_20180517_060-110.csv finished
# nympha-ell_x0-y0_20180517_060-115.csv finished
# nympha-ell_x0-y0_20180517_060-120.csv finished
# nympha-ell_x0-y0_20180517_065-005.csv finished
# nympha-ell_x0-y0_20180517_065-010.csv finished
# nympha-ell_x0-y0_20180517_065-015.csv finished
# nympha-ell_x0-y0_20180517_065-020.csv finished
# nympha-ell_x0-y0_20180517_065-025.csv finished
# nympha-ell_x0-y0_20180517_065-030.csv finished
# nympha-ell_x0-y0_20180517_065-035.csv finished
# nympha-ell_x0-y0_20180517_065-040.csv finished
# nympha-ell_x0-y0_20180517_065-045.csv finished
# nympha-ell_x0-y0_20180517_065-050.csv finished
# nympha-ell_x0-y0_20180517_065-055.csv finished
# nympha-ell_x0-y0_20180517_065-060.csv finished
# nympha-ell_x0-y0_20180517_065-065.csv finished
# nympha-ell_x0-y0_20180517_065-070.csv finished
# nympha-ell_x0-y0_20180517_065-075.csv finished
# nympha-ell_x0-y0_20180517_065-080.csv finished
# nympha-ell_x0-y0_20180517_065-085.csv finished
# nympha-ell_x0-y0_20180517_065-090.csv finished
# nympha-ell_x0-y0_20180517_065-095.csv finished
# nympha-ell_x0-y0_20180517_065-100.csv finished
# nympha-ell_x0-y0_20180517_065-105.csv finished
# nympha-ell_x0-y0_20180517_065-110.csv finished
# nympha-ell_x0-y0_20180517_065-115.csv finished
# nympha-ell_x0-y0_20180517_065-120.csv finished
# nympha-ell_x0-y0_20180517_070-005.csv finished
# nympha-ell_x0-y0_20180517_070-010.csv finished
# nympha-ell_x0-y0_20180517_070-015.csv finished
# nympha-ell_x0-y0_20180517_070-020.csv finished
# nympha-ell_x0-y0_20180517_070-025.csv finished
# nympha-ell_x0-y0_20180517_070-030.csv finished
# nympha-ell_x0-y0_20180517_070-035.csv finished
# nympha-ell_x0-y0_20180517_070-040.csv finished
# nympha-ell_x0-y0_20180517_070-045.csv finished
# nympha-ell_x0-y0_20180517_070-050.csv finished
# nympha-ell_x0-y0_20180517_070-055.csv finished
# nympha-ell_x0-y0_20180517_070-060.csv finished
# nympha-ell_x0-y0_20180517_070-065.csv finished
# nympha-ell_x0-y0_20180517_070-070.csv finished
# nympha-ell_x0-y0_20180517_070-075.csv finished
# nympha-ell_x0-y0_20180517_070-080.csv finished
# nympha-ell_x0-y0_20180517_070-085.csv finished
# nympha-ell_x0-y0_20180517_070-090.csv finished
# nympha-ell_x0-y0_20180517_070-095.csv finished
# nympha-ell_x0-y0_20180517_070-100.csv finished
# nympha-ell_x0-y0_20180517_070-105.csv finished
# nympha-ell_x0-y0_20180517_070-110.csv finished
# nympha-ell_x0-y0_20180517_070-115.csv finished
# nympha-ell_x0-y0_20180517_070-120.csv finished
# nympha-ell_x0-y0_20180517_075-005.csv finished
# nympha-ell_x0-y0_20180517_075-010.csv finished
# nympha-ell_x0-y0_20180517_075-015.csv finished
# nympha-ell_x0-y0_20180517_075-020.csv finished
# nympha-ell_x0-y0_20180517_075-025.csv finished
# nympha-ell_x0-y0_20180517_075-030.csv finished
# nympha-ell_x0-y0_20180517_075-035.csv finished
# nympha-ell_x0-y0_20180517_075-040.csv finished
# nympha-ell_x0-y0_20180517_075-045.csv finished
# nympha-ell_x0-y0_20180517_075-050.csv finished
# nympha-ell_x0-y0_20180517_075-055.csv finished
# nympha-ell_x0-y0_20180517_075-060.csv finished
# nympha-ell_x0-y0_20180517_075-065.csv finished
# nympha-ell_x0-y0_20180517_075-070.csv finished
# nympha-ell_x0-y0_20180517_075-075.csv finished
# nympha-ell_x0-y0_20180517_075-080.csv finished
# nympha-ell_x0-y0_20180517_075-085.csv finished
# nympha-ell_x0-y0_20180517_075-090.csv finished
# nympha-ell_x0-y0_20180517_075-095.csv finished
# nympha-ell_x0-y0_20180517_075-100.csv finished
# nympha-ell_x0-y0_20180517_075-105.csv finished
# nympha-ell_x0-y0_20180517_075-110.csv finished
# nympha-ell_x0-y0_20180517_075-115.csv finished
# nympha-ell_x0-y0_20180517_075-120.csv finished
# nympha-ell_x0-y0_20180517_080-005.csv finished
# nympha-ell_x0-y0_20180517_080-010.csv finished
# nympha-ell_x0-y0_20180517_080-015.csv finished
# nympha-ell_x0-y0_20180517_080-020.csv finished
# nympha-ell_x0-y0_20180517_080-025.csv finished
# nympha-ell_x0-y0_20180517_080-030.csv finished
# nympha-ell_x0-y0_20180517_080-035.csv finished
# nympha-ell_x0-y0_20180517_080-040.csv finished
# nympha-ell_x0-y0_20180517_080-045.csv finished
# nympha-ell_x0-y0_20180517_080-050.csv finished
# nympha-ell_x0-y0_20180517_080-055.csv finished
# nympha-ell_x0-y0_20180517_080-060.csv finished
# nympha-ell_x0-y0_20180517_080-065.csv finished
# nympha-ell_x0-y0_20180517_080-070.csv finished
# nympha-ell_x0-y0_20180517_080-075.csv finished
# nympha-ell_x0-y0_20180517_080-080.csv finished
# nympha-ell_x0-y0_20180517_080-085.csv finished
# nympha-ell_x0-y0_20180517_080-090.csv finished
# nympha-ell_x0-y0_20180517_080-095.csv finished
# nympha-ell_x0-y0_20180517_080-100.csv finished
# nympha-ell_x0-y0_20180517_080-105.csv finished
# nympha-ell_x0-y0_20180517_080-110.csv finished
# nympha-ell_x0-y0_20180517_080-115.csv finished
# nympha-ell_x0-y0_20180517_080-120.csv finished
# nympha-ell_x0-y0_20180517_085-005.csv finished
# nympha-ell_x0-y0_20180517_085-010.csv finished
# nympha-ell_x0-y0_20180517_085-015.csv finished
# nympha-ell_x0-y0_20180517_085-020.csv finished
# nympha-ell_x0-y0_20180517_085-025.csv finished
# nympha-ell_x0-y0_20180517_085-030.csv finished
# nympha-ell_x0-y0_20180517_085-035.csv finished
# nympha-ell_x0-y0_20180517_085-040.csv finished
# nympha-ell_x0-y0_20180517_085-045.csv finished
# nympha-ell_x0-y0_20180517_085-050.csv finished
# nympha-ell_x0-y0_20180517_085-055.csv finished
# nympha-ell_x0-y0_20180517_085-060.csv finished
# nympha-ell_x0-y0_20180517_085-065.csv finished
# nympha-ell_x0-y0_20180517_085-070.csv finished
# nympha-ell_x0-y0_20180517_085-075.csv finished
# nympha-ell_x0-y0_20180517_085-080.csv finished
# nympha-ell_x0-y0_20180517_085-085.csv finished
# nympha-ell_x0-y0_20180517_085-090.csv finished
# nympha-ell_x0-y0_20180517_085-095.csv finished
# nympha-ell_x0-y0_20180517_085-100.csv finished
# nympha-ell_x0-y0_20180517_085-105.csv finished
# nympha-ell_x0-y0_20180517_085-110.csv finished
# nympha-ell_x0-y0_20180517_085-115.csv finished
# nympha-ell_x0-y0_20180517_085-120.csv finished
# nympha-ell_x0-y0_20180517_090-005.csv finished
# nympha-ell_x0-y0_20180517_090-010.csv finished
# nympha-ell_x0-y0_20180517_090-015.csv finished
# nympha-ell_x0-y0_20180517_090-020.csv finished
# nympha-ell_x0-y0_20180517_090-025.csv finished
# nympha-ell_x0-y0_20180517_090-030.csv finished
# nympha-ell_x0-y0_20180517_090-035.csv finished
# nympha-ell_x0-y0_20180517_090-040.csv finished
# nympha-ell_x0-y0_20180517_090-045.csv finished
# nympha-ell_x0-y0_20180517_090-050.csv finished
# nympha-ell_x0-y0_20180517_090-055.csv finished
# nympha-ell_x0-y0_20180517_090-060.csv finished
# nympha-ell_x0-y0_20180517_090-065.csv finished
# nympha-ell_x0-y0_20180517_090-070.csv finished
# nympha-ell_x0-y0_20180517_090-075.csv finished
# nympha-ell_x0-y0_20180517_090-080.csv finished
# nympha-ell_x0-y0_20180517_090-085.csv finished
# nympha-ell_x0-y0_20180517_090-090.csv finished
# nympha-ell_x0-y0_20180517_090-095.csv finished
# nympha-ell_x0-y0_20180517_090-100.csv finished
# nympha-ell_x0-y0_20180517_090-105.csv finished
# nympha-ell_x0-y0_20180517_090-110.csv finished
# nympha-ell_x0-y0_20180517_090-115.csv finished
# nympha-ell_x0-y0_20180517_090-120.csv finished
# nympha-ell_x0-y0_20180517_095-005.csv finished
# nympha-ell_x0-y0_20180517_095-010.csv finished
# nympha-ell_x0-y0_20180517_095-015.csv finished
# nympha-ell_x0-y0_20180517_095-020.csv finished
# nympha-ell_x0-y0_20180517_095-025.csv finished
# nympha-ell_x0-y0_20180517_095-030.csv finished
# nympha-ell_x0-y0_20180517_095-035.csv finished
# nympha-ell_x0-y0_20180517_095-040.csv finished
# nympha-ell_x0-y0_20180517_095-045.csv finished
# nympha-ell_x0-y0_20180517_095-050.csv finished
# nympha-ell_x0-y0_20180517_095-055.csv finished
# nympha-ell_x0-y0_20180517_095-060.csv finished
# nympha-ell_x0-y0_20180517_095-065.csv finished
# nympha-ell_x0-y0_20180517_095-070.csv finished
# nympha-ell_x0-y0_20180517_095-075.csv finished
# nympha-ell_x0-y0_20180517_095-080.csv finished
# nympha-ell_x0-y0_20180517_095-085.csv finished
# nympha-ell_x0-y0_20180517_095-090.csv finished
# nympha-ell_x0-y0_20180517_095-095.csv finished
# nympha-ell_x0-y0_20180517_095-100.csv finished
# nympha-ell_x0-y0_20180517_095-105.csv finished
# nympha-ell_x0-y0_20180517_095-110.csv finished
# nympha-ell_x0-y0_20180517_095-115.csv finished
# nympha-ell_x0-y0_20180517_095-120.csv finished
# nympha-ell_x0-y0_20180517_100-005.csv finished
# nympha-ell_x0-y0_20180517_100-010.csv finished
# nympha-ell_x0-y0_20180517_100-015.csv finished
# nympha-ell_x0-y0_20180517_100-020.csv finished
# nympha-ell_x0-y0_20180517_100-025.csv finished
# nympha-ell_x0-y0_20180517_100-030.csv finished
# nympha-ell_x0-y0_20180517_100-035.csv finished
# nympha-ell_x0-y0_20180517_100-040.csv finished
# nympha-ell_x0-y0_20180517_100-045.csv finished
# nympha-ell_x0-y0_20180517_100-050.csv finished
# nympha-ell_x0-y0_20180517_100-055.csv finished
# nympha-ell_x0-y0_20180517_100-060.csv finished
# nympha-ell_x0-y0_20180517_100-065.csv finished
# nympha-ell_x0-y0_20180517_100-070.csv finished
# nympha-ell_x0-y0_20180517_100-075.csv finished
# nympha-ell_x0-y0_20180517_100-080.csv finished
# nympha-ell_x0-y0_20180517_100-085.csv finished
# nympha-ell_x0-y0_20180517_100-090.csv finished
# nympha-ell_x0-y0_20180517_100-095.csv finished
# nympha-ell_x0-y0_20180517_100-100.csv finished
# nympha-ell_x0-y0_20180517_100-105.csv finished
# nympha-ell_x0-y0_20180517_100-110.csv finished
# nympha-ell_x0-y0_20180517_100-115.csv finished
# nympha-ell_x0-y0_20180517_100-120.csv finished
# nympha-ell_x0-y0_20180517_105-005.csv finished
# nympha-ell_x0-y0_20180517_105-010.csv finished
# nympha-ell_x0-y0_20180517_105-015.csv finished
# nympha-ell_x0-y0_20180517_105-020.csv finished
# nympha-ell_x0-y0_20180517_105-025.csv finished
# nympha-ell_x0-y0_20180517_105-030.csv finished
# nympha-ell_x0-y0_20180517_105-035.csv finished
# nympha-ell_x0-y0_20180517_105-040.csv finished
# nympha-ell_x0-y0_20180517_105-045.csv finished
# nympha-ell_x0-y0_20180517_105-050.csv finished
# nympha-ell_x0-y0_20180517_105-055.csv finished
# nympha-ell_x0-y0_20180517_105-060.csv finished
# nympha-ell_x0-y0_20180517_105-065.csv finished
# nympha-ell_x0-y0_20180517_105-070.csv finished
# nympha-ell_x0-y0_20180517_105-075.csv finished
# nympha-ell_x0-y0_20180517_105-080.csv finished
# nympha-ell_x0-y0_20180517_105-085.csv finished
# nympha-ell_x0-y0_20180517_105-090.csv finished
# nympha-ell_x0-y0_20180517_105-095.csv finished
# nympha-ell_x0-y0_20180517_105-100.csv finished
# nympha-ell_x0-y0_20180517_105-105.csv finished
# nympha-ell_x0-y0_20180517_105-110.csv finished
# nympha-ell_x0-y0_20180517_105-115.csv finished
# nympha-ell_x0-y0_20180517_105-120.csv finished
# nympha-ell_x0-y0_20180517_110-005.csv finished
# nympha-ell_x0-y0_20180517_110-010.csv finished
# nympha-ell_x0-y0_20180517_110-015.csv finished
# nympha-ell_x0-y0_20180517_110-020.csv finished
# nympha-ell_x0-y0_20180517_110-025.csv finished
# nympha-ell_x0-y0_20180517_110-030.csv finished
# nympha-ell_x0-y0_20180517_110-035.csv finished
# nympha-ell_x0-y0_20180517_110-040.csv finished
# nympha-ell_x0-y0_20180517_110-045.csv finished
# nympha-ell_x0-y0_20180517_110-050.csv finished
# nympha-ell_x0-y0_20180517_110-055.csv finished
# nympha-ell_x0-y0_20180517_110-060.csv finished
# nympha-ell_x0-y0_20180517_110-065.csv finished
# nympha-ell_x0-y0_20180517_110-070.csv finished
# nympha-ell_x0-y0_20180517_110-075.csv finished
# nympha-ell_x0-y0_20180517_110-080.csv finished
# nympha-ell_x0-y0_20180517_110-085.csv finished
# nympha-ell_x0-y0_20180517_110-090.csv finished
# nympha-ell_x0-y0_20180517_110-095.csv finished
# nympha-ell_x0-y0_20180517_110-100.csv finished
# nympha-ell_x0-y0_20180517_110-105.csv finished
# nympha-ell_x0-y0_20180517_110-110.csv finished
# nympha-ell_x0-y0_20180517_110-115.csv finished
# nympha-ell_x0-y0_20180517_110-120.csv finished
# nympha-ell_x0-y0_20180517_115-005.csv finished
# nympha-ell_x0-y0_20180517_115-010.csv finished
# nympha-ell_x0-y0_20180517_115-015.csv finished
# nympha-ell_x0-y0_20180517_115-020.csv finished
# nympha-ell_x0-y0_20180517_115-025.csv finished
# nympha-ell_x0-y0_20180517_115-030.csv finished
# nympha-ell_x0-y0_20180517_115-035.csv finished
# nympha-ell_x0-y0_20180517_115-040.csv finished
# nympha-ell_x0-y0_20180517_115-045.csv finished
# nympha-ell_x0-y0_20180517_115-050.csv finished
# nympha-ell_x0-y0_20180517_115-055.csv finished
# nympha-ell_x0-y0_20180517_115-060.csv finished
# nympha-ell_x0-y0_20180517_115-065.csv finished
# nympha-ell_x0-y0_20180517_115-070.csv finished
# nympha-ell_x0-y0_20180517_115-075.csv finished
# nympha-ell_x0-y0_20180517_115-080.csv finished
# nympha-ell_x0-y0_20180517_115-085.csv finished
# nympha-ell_x0-y0_20180517_115-090.csv finished
# nympha-ell_x0-y0_20180517_115-095.csv finished
# nympha-ell_x0-y0_20180517_115-100.csv finished
# nympha-ell_x0-y0_20180517_115-105.csv finished
# nympha-ell_x0-y0_20180517_115-110.csv finished
# nympha-ell_x0-y0_20180517_115-115.csv finished
# nympha-ell_x0-y0_20180517_115-120.csv finished
# nympha-ell_x0-y0_20180517_120-005.csv finished
# nympha-ell_x0-y0_20180517_120-010.csv finished
# nympha-ell_x0-y0_20180517_120-015.csv finished
# nympha-ell_x0-y0_20180517_120-020.csv finished
# nympha-ell_x0-y0_20180517_120-025.csv finished
# nympha-ell_x0-y0_20180517_120-030.csv finished
# nympha-ell_x0-y0_20180517_120-035.csv finished
# nympha-ell_x0-y0_20180517_120-040.csv finished
# nympha-ell_x0-y0_20180517_120-045.csv finished
# nympha-ell_x0-y0_20180517_120-050.csv finished
# nympha-ell_x0-y0_20180517_120-055.csv finished
# nympha-ell_x0-y0_20180517_120-060.csv finished
# nympha-ell_x0-y0_20180517_120-065.csv finished
# nympha-ell_x0-y0_20180517_120-070.csv finished
# nympha-ell_x0-y0_20180517_120-075.csv finished
# nympha-ell_x0-y0_20180517_120-080.csv finished
# nympha-ell_x0-y0_20180517_120-085.csv finished
# nympha-ell_x0-y0_20180517_120-090.csv finished
# nympha-ell_x0-y0_20180517_120-095.csv finished
# nympha-ell_x0-y0_20180517_120-100.csv finished
# nympha-ell_x0-y0_20180517_120-105.csv finished
# nympha-ell_x0-y0_20180517_120-110.csv finished
# nympha-ell_x0-y0_20180517_120-115.csv finished
# nympha-ell_x0-y0_20180517_120-120.csv finished
# completed
