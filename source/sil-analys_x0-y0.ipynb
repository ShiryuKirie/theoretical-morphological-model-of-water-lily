# %% [markdown]
# # initial length

# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from matplotlib import cm

param1 = np.linspace(5, 90, 18)
param2 = np.linspace(5, 90, 18)

Y, X = np.meshgrid(param2, param1)

# %% [markdown]
# # TOP VIEW

# %% [markdown]
# # solidity

# %%
os.chdir('D:/theoretical_waterlily_data/csv/sil_x0-y0')

df_top = pd.read_csv('nympha-ell_silhouette_x0-y0_top_20180711part.csv')
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
ax1.set_aspect('equal')
levels = [0.46, 0.52, 0.58, 0.64, 0.70, 0.76, 0.82, 0.88, 0.94, 1.00]

sld_top = df_top['solidity'].values.reshape([18,18])
im1 = ax1.contourf(X, Y, sld_top, levels, cmap=cm.viridis)
ax1.set_xlabel(r'$x_\mathrm{0}$')
ax1.set_ylabel(r'$y_\mathrm{0}$')

fig1.colorbar(im1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # convexity

# %%
os.chdir('D:/theoretical_waterlily_data/csv/sil_x0-y0')

df_top = pd.read_csv('nympha-ell_silhouette_x0-y0_top_20180711part.csv')
fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
ax2.set_aspect('equal')

cnv_top = df_top['convexity'].values.reshape([18,18])
im2 = ax2.contourf(X, Y, cnv_top,  cmap=cm.viridis)
ax2.set_xlabel(r'$x_\mathrm{0}$')
ax2.set_ylabel(r'$y_\mathrm{0}$')

fig2.colorbar(im2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # SIDE VIEW

# %% [markdown]
# # solidity

# %%
os.chdir('D:/theoretical_waterlily_data/csv/sil_x0-y0')

df_side = pd.read_csv('nympha-ell_silhouette_x0-y0_side_20180711part.csv')
fig3 = plt.figure()
ax3 = fig3.add_subplot(111)
ax3.set_aspect('equal')

sld_side = df_side['solidity'].values.reshape([18,18])
im3 = ax3.contourf(X, Y, sld_side, cmap=cm.viridis)
ax3.set_xlabel(r'$x_\mathrm{0}$')
ax3.set_ylabel(r'$y_\mathrm{0}$')

fig3.colorbar(im3)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # convexity

# %%
os.chdir('D:/theoretical_waterlily_data/csv/sil_x0-y0')

df_side = pd.read_csv('nympha-ell_silhouette_x0-y0_side_20180711part.csv')
fig4 = plt.figure()
ax4 = fig4.add_subplot(111)
ax4.set_aspect('equal')

cnv_side = df_side['convexity'].values.reshape([18,18])
im4 = ax4.contourf(X, Y, cnv_side, cmap=cm.viridis)
ax4.set_xlabel(r'$x_\mathrm{0}$')
ax4.set_ylabel(r'$y_\mathrm{0}$')

fig4.colorbar(im4)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
