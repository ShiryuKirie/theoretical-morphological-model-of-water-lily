# %% [markdown]
# # decreasing rate

# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from matplotlib import cm

param1 = np.linspace(0, 0.05, 26)
param2 = np.linspace(0, 0.05, 26)

Y, X = np.meshgrid(param2, param1)

# %% [markdown]
# # TOP VIEW

# %% [markdown]
# # solidity

# %%
os.chdir('D:/theoretical_waterlily_data/csv/sil_dx1-dy1')

df_top = pd.read_csv('nympha-ell_silhouette_dx1-dy1_top_20180711.csv')
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
ax1.set_aspect('equal')

sld_top = df_top['solidity'].values.reshape([26,26])
im1 = ax1.contourf(X, Y, sld_top, cmap=cm.viridis)
ax1.set_xlabel(r'$dx_\mathrm{1}$')
ax1.set_ylabel(r'$dy_\mathrm{1}$')

fig1.colorbar(im1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # convexity

# %%
os.chdir('D:/theoretical_waterlily_data/csv/sil_dx1-dy1')

df_top = pd.read_csv('nympha-ell_silhouette_dx1-dy1_top_20180711.csv')
fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
ax2.set_aspect('equal')

cnv_top = df_top['convexity'].values.reshape([26,26])
im2 = ax2.contourf(X, Y, cnv_top,  cmap=cm.viridis)
ax2.set_xlabel(r'$dx_\mathrm{1}$')
ax2.set_ylabel(r'$dy_\mathrm{1}$')

fig2.colorbar(im2)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # SIDE VIEW

# %% [markdown]
# # solidity

# %%
os.chdir('D:/theoretical_waterlily_data/csv/sil_dx1-dy1')

df_side = pd.read_csv('nympha-ell_silhouette_dx1-dy1_side_20180711.csv')
fig3 = plt.figure()
ax3 = fig3.add_subplot(111)
ax3.set_aspect('equal')

sld_side = df_side['solidity'].values.reshape([26,26])
im3 = ax3.contourf(X, Y, sld_side, cmap=cm.viridis)
ax3.set_xlabel(r'$dx_\mathrm{1}$')
ax3.set_ylabel(r'$dy_\mathrm{1}$')

fig3.colorbar(im3)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # convexity

# %%
os.chdir('D:/theoretical_waterlily_data/csv/sil_dx1-dy1')

df_side = pd.read_csv('nympha-ell_silhouette_dx1-dy1_side_20180711.csv')
fig4 = plt.figure()
ax4 = fig4.add_subplot(111)
ax4.set_aspect('equal')

cnv_side = df_side['convexity'].values.reshape([26,26])
im4 = ax4.contourf(X, Y, cnv_side, cmap=cm.viridis)
ax4.set_xlabel(r'$dx_\mathrm{1}$')
ax4.set_ylabel(r'$dy_\mathrm{1}$')

fig4.colorbar(im4)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
