# %%
'''
===========================
nympha_ellipse
===========================

Demonstrates a flower of nymphaea as 3D surface(ellipsoid) objects.

'''

from mpl_toolkits.mplot3d import Axes3D
from matplotlib.patches import Circle
import mpl_toolkits.mplot3d.art3d as art3d
import matplotlib.pyplot as plt
import numpy as np
import csv
import os

# setting organ
class Organ :
	def __init__(self, rx, ry, rz, xdeg, zdeg, zpo, hb, col, reso):

		self.rx = rx #minor length
		self.ry = ry #major length
		self.rz = rz 

		self.reso = reso #surfaces resolution

#organ's shape as ellipsoid surface
		u = np.linspace(0, 2 * np.pi, reso)
		v = np.linspace(0, 1/2*np.pi, reso)
		x = self.rx * np.outer(np.cos(u), np.sin(v))
		y = self.ry * np.outer(np.sin(u), np.sin(v))
		z = -self.rz * np.outer(np.ones(np.size(u)), np.cos(v))
		xyz = np.dstack((x, y, z))

#rotate & transfer organ
		self.xdeg = xdeg
		xrot = np.array([[1, 0, 0],
						[0, np.cos(xdeg), -1*np.sin(xdeg)],
						[0, np.sin(xdeg), np.cos(xdeg)]])
		self.zdeg = zdeg
		zrot = np.array([[np.cos(zdeg), -1*np.sin(zdeg), 0],
						[np.sin(zdeg), np.cos(zdeg), 0],
						[0, 0, 1]])

		for i in range(reso):
			for j in range(reso):
				xyz[i,j,:] = np.dot(xrot, xyz[i,j,:].T)
				xyz[i,j,:] = xyz[i,j,:] + [0, self.ry * np.cos(xdeg) + db, self.ry * np.sin(xdeg) + zpo]
				xyz[i,j,:] = np.dot(zrot, xyz[i,j,:].T)
				if record == True:
					csvWriter.writerow(xyz[i,j,:]) #record in csv

		self.col = col

##########################################################################################

#setting parameter of each organ

def orgforms(dx1 = 0.040, dx2 = 0.001, x0 = 10, xt = 2.0, txi = 20, dy1 = 0.020, dy2 = 0.004, y0= 35, yt = 12.0, tyi = 20):
#parameter to set size of ellipsoid

	rxs = np.linspace(0, n_organ-1, n_organ) # minor length
	rxs[0:txi] = x0 - x0 * dx1 * rxs[0:txi] # x = x0 - ai and  a = x0*dx1
	rxs[txi:n_organ] = xt - x0 * dx2 * (rxs[txi:n_organ] - txi) # x = xt - b(i-tx) and b = x0*dx2 and tx = txi-1
    
	rys = np.linspace(0, n_organ-1, n_organ) # major length
	rys[0:tyi] = y0 - y0 * dy1 * rys[0:tyi] # y = y0 - ai and  a = y0*dy1
	rys[tyi:n_organ] = yt - y0 * dy2 * (rys[tyi:n_organ] - tyi) # y = yt - b(i-ty) and b = y0*dy2 and ty = tyi-1

	#the point finishing transition
	tmax = max([txi, tyi]) 

	#organs swell
	rzs = np.zeros(n_organ)
	for i in range(n_organ):
		if i < tmax:
			rzs[i] = 0 #mode1
		else:
			rzs[i] = 0 #mode2

	return (rxs, rys, tmax, rzs)

####################################################################
#parameter to elevate each organ

def orgposi(pitch = -0.01):

#parameter to rotate each organ along z-axis
	zdegs = np.zeros(n_organ)
	zdegs[0] = 0
	zdegs[1] = np.pi
	zdegs[2] = np.pi * 3/2
	zdegs[3] = np.pi * 1/2
	for i in range(4, n_organ):
		zdegs[i] = zdegs[i - 1] + 137.5/180 *  np.pi

# height where each organ is put 
	zpos = np.zeros(n_organ)
	dzps = np.exp(pitch * zdegs)
	zpos[0] = 0
	zpos[1] = 0
	zpos[2] = 0
	zpos[3] = 0
	for i in range (1, n_organ):
		zpos[i] = zpos[i-1] + dzps[i]
	zpos = zpos/max(zpos) * hb

	return (zdegs, zpos)

########################################################################

def elevangle(max_ang = np.pi / 4, min_ang = np.pi / 4):

	xdegs = np.zeros(n_organ)
	xdegs[0:4] = min_ang
	for i in range(4, n_organ):
		if i < tmax:
			xdegs[i] = xdegs[i - 1] + (max_ang - min_ang) / (tmax-4)
		else:
			xdegs[i] = 90/180 * np.pi

	return xdegs
##########################################################################################
#setting

n_organ = 100
reso = 90

db = 10 #half of Base' s Diameter
hb = 5 #Height of Base
bu = np.linspace(0, 2 * np.pi, reso)

#upper part of base
bux = np.outer(db * np.cos(bu), np.ones(np.size(bu)))
buy = np.outer(db * np.sin(bu), np.ones(np.size(bu)))
buz = np.outer(np.ones(np.size(bu)), np.linspace(0, hb, reso))

#uppermost part of base
upp = Circle((0, 0), db, color = "red")

#basal part of base
bv = np.linspace(0, 1/2*np.pi, reso)
bbx = -db * np.outer(np.cos(bu), np.sin(bv))
bby = -db * np.outer(np.sin(bu), np.sin(bv))
bbz = -db * np.outer(np.ones(np.size(bu)), np.cos(bv))

##########################################################################################

#csv file
#Trueでファイルに書き出し
os.chdir('D:/theoretical_waterlily_data/csv/pitch') #データが大きいのでハードディスクに保管
record = True
namehead = "nympha-ell_pitch_20180514"

for curr_pitch in range(0, 1001, 10):
    namebody = '_' + str(int(curr_pitch)).zfill(4)
    csv_coo = open(namehead + namebody + '.csv', 'x', newline='')
    csvWriter = csv.writer(csv_coo)
    for i in range(reso):
        for j in range(reso):
            csvWriter.writerow([bux[i,j], buy[i,j], buz[i,j]])
            csvWriter.writerow([bbx[i,j], bby[i,j], bbz[i,j]])
                    
    #draw each organ
    rxs, rys, tmax, rzs = orgforms()
    zdegs, zpos = orgposi(pitch = -0.001 * curr_pitch)
    xdegs = elevangle() 


    for n in range(n_organ):
        rx = rxs[n]
        ry = rys[n]        
        rz = rzs[n]
        xdeg = xdegs[n]
        zdeg = zdegs[n]
        zpo = zpos[n]
        col = "red"
        organ = Organ(rx, ry, rz, xdeg, zdeg, zpo, hb, col, reso)
        
    if record == True:
        csv_coo.close()
        print(namehead + namebody + '.csv finished')

print("completed")
# Out:
# nympha-ell_pitch_20180514_0000.csv finished
# nympha-ell_pitch_20180514_0010.csv finished
# nympha-ell_pitch_20180514_0020.csv finished
# nympha-ell_pitch_20180514_0030.csv finished
# nympha-ell_pitch_20180514_0040.csv finished
# nympha-ell_pitch_20180514_0050.csv finished
# nympha-ell_pitch_20180514_0060.csv finished
# nympha-ell_pitch_20180514_0070.csv finished
# nympha-ell_pitch_20180514_0080.csv finished
# nympha-ell_pitch_20180514_0090.csv finished
# nympha-ell_pitch_20180514_0100.csv finished
# nympha-ell_pitch_20180514_0110.csv finished
# nympha-ell_pitch_20180514_0120.csv finished
# nympha-ell_pitch_20180514_0130.csv finished
# nympha-ell_pitch_20180514_0140.csv finished
# nympha-ell_pitch_20180514_0150.csv finished
# nympha-ell_pitch_20180514_0160.csv finished
# nympha-ell_pitch_20180514_0170.csv finished
# nympha-ell_pitch_20180514_0180.csv finished
# nympha-ell_pitch_20180514_0190.csv finished
# nympha-ell_pitch_20180514_0200.csv finished
# nympha-ell_pitch_20180514_0210.csv finished
# nympha-ell_pitch_20180514_0220.csv finished
# nympha-ell_pitch_20180514_0230.csv finished
# nympha-ell_pitch_20180514_0240.csv finished
# nympha-ell_pitch_20180514_0250.csv finished
# nympha-ell_pitch_20180514_0260.csv finished
# nympha-ell_pitch_20180514_0270.csv finished
# nympha-ell_pitch_20180514_0280.csv finished
# nympha-ell_pitch_20180514_0290.csv finished
# nympha-ell_pitch_20180514_0300.csv finished
# nympha-ell_pitch_20180514_0310.csv finished
# nympha-ell_pitch_20180514_0320.csv finished
# nympha-ell_pitch_20180514_0330.csv finished
# nympha-ell_pitch_20180514_0340.csv finished
# nympha-ell_pitch_20180514_0350.csv finished
# nympha-ell_pitch_20180514_0360.csv finished
# nympha-ell_pitch_20180514_0370.csv finished
# nympha-ell_pitch_20180514_0380.csv finished
# nympha-ell_pitch_20180514_0390.csv finished
# nympha-ell_pitch_20180514_0400.csv finished
# nympha-ell_pitch_20180514_0410.csv finished
# nympha-ell_pitch_20180514_0420.csv finished
# nympha-ell_pitch_20180514_0430.csv finished
# nympha-ell_pitch_20180514_0440.csv finished
# nympha-ell_pitch_20180514_0450.csv finished
# nympha-ell_pitch_20180514_0460.csv finished
# nympha-ell_pitch_20180514_0470.csv finished
# nympha-ell_pitch_20180514_0480.csv finished
# nympha-ell_pitch_20180514_0490.csv finished
# nympha-ell_pitch_20180514_0500.csv finished
# nympha-ell_pitch_20180514_0510.csv finished
# nympha-ell_pitch_20180514_0520.csv finished
# nympha-ell_pitch_20180514_0530.csv finished
# nympha-ell_pitch_20180514_0540.csv finished
# nympha-ell_pitch_20180514_0550.csv finished
# nympha-ell_pitch_20180514_0560.csv finished
# nympha-ell_pitch_20180514_0570.csv finished
# nympha-ell_pitch_20180514_0580.csv finished
# nympha-ell_pitch_20180514_0590.csv finished
# nympha-ell_pitch_20180514_0600.csv finished
# nympha-ell_pitch_20180514_0610.csv finished
# nympha-ell_pitch_20180514_0620.csv finished
# nympha-ell_pitch_20180514_0630.csv finished
# nympha-ell_pitch_20180514_0640.csv finished
# nympha-ell_pitch_20180514_0650.csv finished
# nympha-ell_pitch_20180514_0660.csv finished
# nympha-ell_pitch_20180514_0670.csv finished
# nympha-ell_pitch_20180514_0680.csv finished
# nympha-ell_pitch_20180514_0690.csv finished
# nympha-ell_pitch_20180514_0700.csv finished
# nympha-ell_pitch_20180514_0710.csv finished
# nympha-ell_pitch_20180514_0720.csv finished
# nympha-ell_pitch_20180514_0730.csv finished
# nympha-ell_pitch_20180514_0740.csv finished
# nympha-ell_pitch_20180514_0750.csv finished
# nympha-ell_pitch_20180514_0760.csv finished
# nympha-ell_pitch_20180514_0770.csv finished
# nympha-ell_pitch_20180514_0780.csv finished
# nympha-ell_pitch_20180514_0790.csv finished
# nympha-ell_pitch_20180514_0800.csv finished
# nympha-ell_pitch_20180514_0810.csv finished
# nympha-ell_pitch_20180514_0820.csv finished
# nympha-ell_pitch_20180514_0830.csv finished
# nympha-ell_pitch_20180514_0840.csv finished
# nympha-ell_pitch_20180514_0850.csv finished
# nympha-ell_pitch_20180514_0860.csv finished
# nympha-ell_pitch_20180514_0870.csv finished
# nympha-ell_pitch_20180514_0880.csv finished
# nympha-ell_pitch_20180514_0890.csv finished
# nympha-ell_pitch_20180514_0900.csv finished
# nympha-ell_pitch_20180514_0910.csv finished
# nympha-ell_pitch_20180514_0920.csv finished
# nympha-ell_pitch_20180514_0930.csv finished
# nympha-ell_pitch_20180514_0940.csv finished
# nympha-ell_pitch_20180514_0950.csv finished
# nympha-ell_pitch_20180514_0960.csv finished
# nympha-ell_pitch_20180514_0970.csv finished
# nympha-ell_pitch_20180514_0980.csv finished
# nympha-ell_pitch_20180514_0990.csv finished
# nympha-ell_pitch_20180514_1000.csv finished
# completed
